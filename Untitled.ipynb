# %%
import json
from pprint import pprint
import pandas as pd
import numpy as np
#data loading starts
with open('datascience.json',encoding="utf8") as f:
    data = json.load(f)
#pprint(data['GraphImages'][0],indent=3)

#data loading ends, cleaning starts

train = pd.DataFrame.from_dict(data['GraphImages'])
train=train[train['__typename']=='GraphImage']
train['edge_media_preview_like']=train['edge_media_preview_like'].apply(lambda x: x['count'])
train['edge_media_to_comment']=train['edge_media_to_comment'].apply(lambda x: x['count'])
train['dimensions_height']=train['dimensions'].apply(lambda x: x['height'])
train['dimensions_width']=train['dimensions'].apply(lambda x: x['width'])
train.drop(['__typename','dimensions','gating_info','is_video','id','media_preview','thumbnail_resources','owner','thumbnail_src','video_view_count','urls'], axis=1,inplace=True)
train['edge_media_to_caption']=train['edge_media_to_caption'].apply(lambda x: x['edges'])
train=train[['shortcode','username','display_url','edge_media_preview_like','comments_disabled','edge_media_to_comment','dimensions_height','dimensions_width','edge_media_to_caption','tags','taken_at_timestamp']].reset_index()
train.drop(['index'], axis=1,inplace=True)
#train['tags'].fillna(0,inplace=True)
# Out:
# 41
#       shortcode     username  \
# 0   BuLSId5BiDc  datascience
# 1   Bi0L2wmh3bZ  datascience
# 2   Bi0Lp2dhv4D  datascience
# 3   BfU_DIBAaFo  datascience
# 4   BeoWzd9nRSF  datascience
# 5   BeoWiIPn4Hy  datascience
# 6   BemQM09A0qL  datascience
# 7   Bd9r-b8gwxa  datascience
# 8   Bd9rno9gZqu  datascience
# 9   BatdcADgGNe  datascience
# 10  BatdXx4A2ZH  datascience
# 11  Baay1W6AV7x  datascience
# 12  BZ8_fT0gpTH  datascience
# 13  BS90TJEAiQp  datascience
# 14  BRntAqLAKuq  datascience
#
#                                           display_url  \
# 0   https://scontent-bom1-2.cdninstagram.com/vp/4e...
# 1   https://scontent-bom1-2.cdninstagram.com/vp/80...
# 2   https://scontent-bom1-2.cdninstagram.com/vp/86...
# 3   https://scontent-bom1-2.cdninstagram.com/vp/96...
# 4   https://scontent-bom1-2.cdninstagram.com/vp/14...
# 5   https://scontent-bom1-2.cdninstagram.com/vp/0f...
# 6   https://scontent-bom1-2.cdninstagram.com/vp/8d...
# 7   https://scontent-bom1-2.cdninstagram.com/vp/b3...
# 8   https://scontent-bom1-2.cdninstagram.com/vp/d9...
# 9   https://scontent-bom1-2.cdninstagram.com/vp/ee...
# 10  https://scontent-bom1-2.cdninstagram.com/vp/39...
# 11  https://scontent-bom1-2.cdninstagram.com/vp/86...
# 12  https://scontent-bom1-2.cdninstagram.com/vp/8f...
# 13  https://scontent-bom1-2.cdninstagram.com/vp/8e...
# 14  https://scontent-bom1-2.cdninstagram.com/vp/54...
#
#     edge_media_preview_like  comments_disabled  edge_media_to_comment  \
# 0                        40              False                      1
# 1                        17              False                      2
# 2                        16              False                      0
# 3                        57              False                      3
# 4                        33              False                      1
# 5                        31              False                      0
# 6                        61              False                      2
# 7                        28              False                      0
# 8                        20              False                      1
# 9                        15              False                      1
# 10                       16              False                      0
# 11                       18              False                      0
# 12                       31              False                      0
# 13                       22              False                      1
# 14                        9              False                      0
#
#     dimensions_height  dimensions_width  \
# 0                 750               750
# 1                1080              1080
# 2                 640               640
# 3                1080              1080
# 4                1080              1080
# 5                 640               640
# 6                 640               640
# 7                 750               750
# 8                1080              1080
# 9                1080              1080
# 10               1080              1080
# 11                750               750
# 12                480               480
# 13               1080              1080
# 14                718              1080
#
#                                 edge_media_to_caption  \
# 0   [{'node': {'text': 'Data Science and Technolog...
# 1   [{'node': {'text': 'IRO Prelims souvenir shirt...
# 2   [{'node': {'text': '2018 IRO Preliminaries and...
# 3               [{'node': {'text': 'robot at work'}}]
# 4   [{'node': {'text': 'When you’re with talented ...
# 5   [{'node': {'text': 'A world of wonders waiting...
# 6   [{'node': {'text': 'Innovative Robotics for Sc...
# 7   [{'node': {'text': '#roboticseminar #robotics'}}]
# 8   [{'node': {'text': '#internationalrobotolympid...
# 9   [{'node': {'text': '#robotics #dstc #sembreak ...
# 10  [{'node': {'text': '#robotics #sumobot #sembre...
# 11        [{'node': {'text': 'the best sembreak 😀'}}]
# 12  [{'node': {'text': 'Great things start from sm...
# 13                                                 []
# 14                                                 []
#
#                                                  tags  taken_at_timestamp
# 0                                                  []          1550821828
# 1                                                  []          1526424465
# 2                                                  []          1526424359
# 3                                                  []          1518935112
# 4                                                  []          1517437617
# 5                                                  []          1517437475
# 6   [roboticseminar, robot, robotics, dstc, roboti...          1517367046
# 7                          [roboticseminar, robotics]          1516005877
# 8      [20thIRO, robotics, internationalrobotolympid]          1516005690
# 9                 [robotics, dstc, sembreak, sumobot]          1509018933
# 10                [robotics, dstc, sembreak, sumobot]          1509018898
# 11                                                 []          1508392616
# 12  [robotgames, robotics, dstc, inexrobots, inex,...          1507392618
# 13                                                NaN          1492387920
# 14                                                NaN          1489498418

# %%
#comment cleaning
x=train.iloc[:,8:9].values.tolist()
x=[val[0] for val in x ]
modified_comments=[]
for val in x:
    if len(val)==0:
        modified_comments.append('NEUTRAL')
    else :
        modified_comments.append(val[0]['node']['text'])

train['edge_media_to_caption']=modified_comments
train.to_csv(r'data_science partially cleaned ordered.csv')
# Out:
#       shortcode     username  \
# 0   BuLSId5BiDc  datascience
# 1   Bi0L2wmh3bZ  datascience
# 2   Bi0Lp2dhv4D  datascience
# 3   BfU_DIBAaFo  datascience
# 4   BeoWzd9nRSF  datascience
# 5   BeoWiIPn4Hy  datascience
# 6   BemQM09A0qL  datascience
# 7   Bd9r-b8gwxa  datascience
# 8   Bd9rno9gZqu  datascience
# 9   BatdcADgGNe  datascience
# 10  BatdXx4A2ZH  datascience
# 11  Baay1W6AV7x  datascience
# 12  BZ8_fT0gpTH  datascience
# 13  BS90TJEAiQp  datascience
# 14  BRntAqLAKuq  datascience
#
#                                           display_url  \
# 0   https://scontent-bom1-2.cdninstagram.com/vp/4e...
# 1   https://scontent-bom1-2.cdninstagram.com/vp/80...
# 2   https://scontent-bom1-2.cdninstagram.com/vp/86...
# 3   https://scontent-bom1-2.cdninstagram.com/vp/96...
# 4   https://scontent-bom1-2.cdninstagram.com/vp/14...
# 5   https://scontent-bom1-2.cdninstagram.com/vp/0f...
# 6   https://scontent-bom1-2.cdninstagram.com/vp/8d...
# 7   https://scontent-bom1-2.cdninstagram.com/vp/b3...
# 8   https://scontent-bom1-2.cdninstagram.com/vp/d9...
# 9   https://scontent-bom1-2.cdninstagram.com/vp/ee...
# 10  https://scontent-bom1-2.cdninstagram.com/vp/39...
# 11  https://scontent-bom1-2.cdninstagram.com/vp/86...
# 12  https://scontent-bom1-2.cdninstagram.com/vp/8f...
# 13  https://scontent-bom1-2.cdninstagram.com/vp/8e...
# 14  https://scontent-bom1-2.cdninstagram.com/vp/54...
#
#     edge_media_preview_like  comments_disabled  edge_media_to_comment  \
# 0                        40              False                      1
# 1                        17              False                      2
# 2                        16              False                      0
# 3                        57              False                      3
# 4                        33              False                      1
# 5                        31              False                      0
# 6                        61              False                      2
# 7                        28              False                      0
# 8                        20              False                      1
# 9                        15              False                      1
# 10                       16              False                      0
# 11                       18              False                      0
# 12                       31              False                      0
# 13                       22              False                      1
# 14                        9              False                      0
#
#     dimensions_height  dimensions_width  \
# 0                 750               750
# 1                1080              1080
# 2                 640               640
# 3                1080              1080
# 4                1080              1080
# 5                 640               640
# 6                 640               640
# 7                 750               750
# 8                1080              1080
# 9                1080              1080
# 10               1080              1080
# 11                750               750
# 12                480               480
# 13               1080              1080
# 14                718              1080
#
#                                 edge_media_to_caption  \
# 0   Data Science and Technology Corporation at Kon...
# 1             IRO Prelims souvenir shirt for everyone
# 2        2018 IRO Preliminaries and Summer Sumo Games
# 3                                       robot at work
# 4   When you’re with talented and creative teacher...
# 5   A world of wonders waiting to be discovered @ ...
# 6   Innovative Robotics for Schools: Strategies to...
# 7                           #roboticseminar #robotics
# 8      #internationalrobotolympid #20thIRO  #robotics
# 9                  #robotics #dstc #sembreak #sumobot
# 10     #robotics #sumobot #sembreak #dstc #robotics #
# 11                                the best sembreak 😀
# 12  Great things start from small beginnings... Ma...
# 13                                            NEUTRAL
# 14                                            NEUTRAL
#
#                                                  tags  taken_at_timestamp
# 0                                                  []          1550821828
# 1                                                  []          1526424465
# 2                                                  []          1526424359
# 3                                                  []          1518935112
# 4                                                  []          1517437617
# 5                                                  []          1517437475
# 6   [roboticseminar, robot, robotics, dstc, roboti...          1517367046
# 7                          [roboticseminar, robotics]          1516005877
# 8      [20thIRO, robotics, internationalrobotolympid]          1516005690
# 9                 [robotics, dstc, sembreak, sumobot]          1509018933
# 10                [robotics, dstc, sembreak, sumobot]          1509018898
# 11                                                 []          1508392616
# 12  [robotgames, robotics, dstc, inexrobots, inex,...          1507392618
# 13                                                NaN          1492387920
# 14                                                NaN          1489498418

# %%
y=train.iloc[:,9:10].values.tolist()
y
# Out:
# [[[]],
#  [[]],
#  [[]],
#  [[]],
#  [[]],
#  [[]],
#  [['roboticseminar',
#    'robot',
#    'robotics',
#    'dstc',
#    'robotinnovation',
#    'datascience',
#    'creative']],
#  [['roboticseminar', 'robotics']],
#  [['20thIRO', 'robotics', 'internationalrobotolympid']],
#  [['robotics', 'dstc', 'sembreak', 'sumobot']],
#  [['robotics', 'dstc', 'sembreak', 'sumobot']],
#  [[]],
#  [['robotgames', 'robotics', 'dstc', 'inexrobots', 'inex', 'worldrobotgames']],
#  [0],
#  [0],
#  [['DSTCSummerRobotics2017', 'DSTCSummerSumoGames2017']],
#  [['roboticsworkshop2017',
#    'sumobotcompetition',
#    'DSTCSummerRobotics2017',
#    'roboticsworkshop',
#    'iot',
#    'roboticscamp',
#    'inex',
#    'summersumogames2017']],
#  [['summer2017goals',
#    'roboticsworkshop2017',
#    'summer2017ph',
#    'DSTCSummerRobotics2017',
#    'DSTCSummerSumoGames2017',
#    'summer2017',
#    'roboticsworkshop',
#    'roboticscamp',
#    'inex',
#    'summer2017ready',
#    'summersumogames2017']],
#  [0],
#  [0],
#  [[]],
#  [[]],
#  [[]],
#  [[]],
#  [0],
#  [0],
#  [[]],
#  [[]],
#  [[]],
#  [['deped', 'k12nstf', 'depednstf', 'pinoyrobotgames']],
#  [['studyfun', 'k12', 'teacherstraining', 'taiwaneducation']],
#  [[]],
#  [[]],
#  [[]],
#  [['friday', 'tgif']],
#  [['July']],
#  [[]],
#  [['brother', 'sibling', 'sister']],
#  [['qotd']],
#  [['robots', 'school']],
#  [['tgif']],
#  [['printer', 'philippines', '3dprinter']],
#  [['happyfathersday']],
#  [['ironman', 'happyindependenceday']],
#  [[]],
#  [['finals', 'nba', 'game3']],
#  [[]]]
