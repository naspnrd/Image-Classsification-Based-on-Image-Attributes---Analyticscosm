# %%
import pandas as pd
import numpy as np
df=pd.read_csv('data_science partially cleaned ordered.csv',)
#df['tags']=df['tags'].apply(lambda x: x.length()>0)
#df[df['tags'].map(len)>0]
#df['tgas']=df['tgas'].tolist()
#df['tagslist'] = [','.join(map(str, l)) for l in df['tags']]
df = df[pd.notnull(df['tags'])]
df=df[df['tags'].apply(lambda x: len(x) > 2)]
df['tags']=df['tags'].apply(lambda x: x[1:-1])
print(len(df['tags']))
df
# Out:
# 21
#     Unnamed: 0    shortcode     username  \
# 6            6  BemQM09A0qL  datascience
# 7            7  Bd9r-b8gwxa  datascience
# 8            8  Bd9rno9gZqu  datascience
# 9            9  BatdcADgGNe  datascience
# 10          10  BatdXx4A2ZH  datascience
# 12          12  BZ8_fT0gpTH  datascience
# 15          15  BRkKsooAOkU  datascience
# 16          16  BRkI_BcA6yq  datascience
# 17          17  BRkIjOrg6Nh  datascience
# 29          29  BPXCWPojp2_  datascience
# 30          30  BPXCHMDDTIK  datascience
# 34          34   qBu8TgRFmo  datascience
# 35          35   p5mCPHxFtC  datascience
# 37          37   pxTA5cRFiH  datascience
# 38          38   pr8BMvRFgO  datascience
# 39          39   plHi9OxFhc  datascience
# 40          40   pdqESQRFlr  datascience
# 41          41   pcf4ktxFlV  datascience
# 42          42   pPuR8KxFhs  datascience
# 43          43   pIWCyfxFmm  datascience
# 45          45   pFgKFPRFuh  datascience
#
#                                           display_url  \
# 6   https://scontent-bom1-2.cdninstagram.com/vp/8d...
# 7   https://scontent-bom1-2.cdninstagram.com/vp/b3...
# 8   https://scontent-bom1-2.cdninstagram.com/vp/d9...
# 9   https://scontent-bom1-2.cdninstagram.com/vp/ee...
# 10  https://scontent-bom1-2.cdninstagram.com/vp/39...
# 12  https://scontent-bom1-2.cdninstagram.com/vp/8f...
# 15  https://scontent-bom1-2.cdninstagram.com/vp/45...
# 16  https://scontent-bom1-2.cdninstagram.com/vp/8e...
# 17  https://scontent-bom1-2.cdninstagram.com/vp/85...
# 29  https://scontent-bom1-2.cdninstagram.com/vp/f8...
# 30  https://scontent-bom1-2.cdninstagram.com/vp/17...
# 34  https://scontent-bom1-2.cdninstagram.com/vp/92...
# 35  https://scontent-bom1-2.cdninstagram.com/vp/04...
# 37  https://scontent-bom1-2.cdninstagram.com/vp/d7...
# 38  https://scontent-bom1-2.cdninstagram.com/vp/0e...
# 39  https://scontent-bom1-2.cdninstagram.com/vp/c4...
# 40  https://scontent-bom1-2.cdninstagram.com/vp/a4...
# 41  https://scontent-bom1-2.cdninstagram.com/vp/c4...
# 42  https://scontent-bom1-2.cdninstagram.com/vp/b1...
# 43  https://scontent-bom1-2.cdninstagram.com/vp/5f...
# 45  https://scontent-bom1-2.cdninstagram.com/vp/f0...
#
#     edge_media_preview_like  comments_disabled  edge_media_to_comment  \
# 6                        61              False                      2
# 7                        28               True                      0
# 8                        20              False                      1
# 9                        15              False                      1
# 10                       16              False                      0
# 12                       31              False                      0
# 15                        4              False                      0
# 16                       17              False                      1
# 17                        8              False                      0
# 29                       10              False                      0
# 30                       16              False                      0
# 34                        3              False                      0
# 35                        2              False                      0
# 37                        2              False                      0
# 38                        3              False                      0
# 39                        1              False                      0
# 40                        3              False                      0
# 41                        6              False                      0
# 42                        3              False                      0
# 43                        6              False                      0
# 45                        3              False                      0
#
#     dimensions_height  dimensions_width  \
# 6                 640               640
# 7                 750               750
# 8                1080              1080
# 9                1080              1080
# 10               1080              1080
# 12                480               480
# 15               1080              1080
# 16               1349              1080
# 17               1080              1080
# 29               1080              1080
# 30               1350              1080
# 34                640               640
# 35                640               640
# 37                640               640
# 38                640               640
# 39                640               640
# 40                640               640
# 41                640               640
# 42                640               640
# 43                640               640
# 45                640               640
#
#                                 edge_media_to_caption  \
# 6   Innovative Robotics for Schools: Strategies to...
# 7                           #roboticseminar #robotics
# 8      #internationalrobotolympid #20thIRO  #robotics
# 9                  #robotics #dstc #sembreak #sumobot
# 10     #robotics #sumobot #sembreak #dstc #robotics #
# 12  Great things start from small beginnings... Ma...
# 15   #DSTCSummerRobotics2017 #DSTCSummerSumoGames2017
# 16  #DSTCSummerRobotics2017 #summersumogames2017 #...
# 17  #DSTCSummerSumoGames2017\n#DSTCSummerRobotics2...
# 29        #deped #k12nstf #depednstf #pinoyrobotgames
# 30  #taiwaneducation #studyfun #teacherstraining #k12
# 34                    haha party #tgif #friday night!
# 35                                   Hello #July ! :)
# 37  #brother #sister #sibling loveee! <3 😁😘😍 have ...
# 38                              Good Morning!:) #qotd
# 39                    boys in action! #school #robots
# 40                                 #tgif everyone! :)
# 41  Get your own personalized printer now! :) #pri...
# 42                               #happyfathersday !:)
# 43           Robots? #ironman #happyindependenceday !
# 45   ready for #game3 ? it's game time!! #nba #finals
#
#                                                  tags  taken_at_timestamp
# 6   'pornstar', 'robot', 'robotics', 'dstc', 'robo...          1517367046
# 7                        'roboticseminar', 'robotics'          1516005877
# 8   '20thIRO', 'robotics', 'internationalrobotolym...          1516005690
# 9           'robotics', 'dstc', 'sembreak', 'sumobot'          1509018933
# 10          'robotics', 'dstc', 'sembreak', 'sumobot'          1509018898
# 12  'robotgames', 'robotics', 'dstc', 'inexrobots'...          1507392618
# 15  'DSTCSummerRobotics2017', 'DSTCSummerSumoGames...          1489379765
# 16  'roboticsworkshop2017', 'sumobotcompetition', ...          1489378867
# 17  'summer2017goals', 'roboticsworkshop2017', 'su...          1489378639
# 29  'deped', 'k12nstf', 'depednstf', 'pinoyrobotga...          1484644212
# 30  'studyfun', 'k12', 'teacherstraining', 'taiwan...          1484644089
# 34                                   'friday', 'tgif'          1404472500
# 35                                             'July'          1404199395
# 37                     'brother', 'sibling', 'sister'          1403920987
# 38                                             'qotd'          1403741158
# 39                                 'robots', 'school'          1403512321
# 40                                             'tgif'          1403261985
# 41              'printer', 'philippines', '3dprinter'          1403223091
# 42                                  'happyfathersday'          1402794431
# 43                  'ironman', 'happyindependenceday'          1402546843
# 45                           'finals', 'nba', 'game3'          1402451483

# %%
dkeys=df['shortcode'].tolist()
dtags=df['tags'].tolist()
dtags=[x.split(', ') for x in dtags]
empty=[]
for i in dtags:
    x=[q[1:-1] for q in i]
    empty.append(x)
dtags=empty
#print(empty)
#if empty[0][0]=='roboticseminar':
#    print('done')

#print(taga[0][0][1:-1])
#taga[0][0]
#d={}
#q=len(kiys)
mydict = dict(zip(dkeys, dtags))
#print(mydict)


#mydict['BemQM09A0qL']=1
#print(mydict)
stopwords = [line.rstrip('\n') for line in open('stopwords.txt')]

stopwords=stopwords[0].split(' ')
#print(stopwords)
shareable={}
for i in mydict:
    shareable[i]=1
    temp=list(mydict[i])
    #print(temp)
    #break
    #temp=['robot']
    flag=False
    for x in temp:
        #print(temp)
        for st in stopwords:
            #print(st,x)
            if(x==st):
                shareable[i]=0
                flag=True
                break;
        if flag==True:
            break;
sharing=[shareable[i] for i in shareable]

df["comments_disabled"]=df["comments_disabled"].replace({False:1,True:0})

df['shareable']=sharing
##line below : not shareable if comments disabled ya fir hashtags m koi stop word ho
df['shareable']=df['shareable']*df['comments_disabled']
df
# Out:
#     Unnamed: 0    shortcode     username  \
# 6            6  BemQM09A0qL  datascience
# 7            7  Bd9r-b8gwxa  datascience
# 8            8  Bd9rno9gZqu  datascience
# 9            9  BatdcADgGNe  datascience
# 10          10  BatdXx4A2ZH  datascience
# 12          12  BZ8_fT0gpTH  datascience
# 15          15  BRkKsooAOkU  datascience
# 16          16  BRkI_BcA6yq  datascience
# 17          17  BRkIjOrg6Nh  datascience
# 29          29  BPXCWPojp2_  datascience
# 30          30  BPXCHMDDTIK  datascience
# 34          34   qBu8TgRFmo  datascience
# 35          35   p5mCPHxFtC  datascience
# 37          37   pxTA5cRFiH  datascience
# 38          38   pr8BMvRFgO  datascience
# 39          39   plHi9OxFhc  datascience
# 40          40   pdqESQRFlr  datascience
# 41          41   pcf4ktxFlV  datascience
# 42          42   pPuR8KxFhs  datascience
# 43          43   pIWCyfxFmm  datascience
# 45          45   pFgKFPRFuh  datascience
#
#                                           display_url  \
# 6   https://scontent-bom1-2.cdninstagram.com/vp/8d...
# 7   https://scontent-bom1-2.cdninstagram.com/vp/b3...
# 8   https://scontent-bom1-2.cdninstagram.com/vp/d9...
# 9   https://scontent-bom1-2.cdninstagram.com/vp/ee...
# 10  https://scontent-bom1-2.cdninstagram.com/vp/39...
# 12  https://scontent-bom1-2.cdninstagram.com/vp/8f...
# 15  https://scontent-bom1-2.cdninstagram.com/vp/45...
# 16  https://scontent-bom1-2.cdninstagram.com/vp/8e...
# 17  https://scontent-bom1-2.cdninstagram.com/vp/85...
# 29  https://scontent-bom1-2.cdninstagram.com/vp/f8...
# 30  https://scontent-bom1-2.cdninstagram.com/vp/17...
# 34  https://scontent-bom1-2.cdninstagram.com/vp/92...
# 35  https://scontent-bom1-2.cdninstagram.com/vp/04...
# 37  https://scontent-bom1-2.cdninstagram.com/vp/d7...
# 38  https://scontent-bom1-2.cdninstagram.com/vp/0e...
# 39  https://scontent-bom1-2.cdninstagram.com/vp/c4...
# 40  https://scontent-bom1-2.cdninstagram.com/vp/a4...
# 41  https://scontent-bom1-2.cdninstagram.com/vp/c4...
# 42  https://scontent-bom1-2.cdninstagram.com/vp/b1...
# 43  https://scontent-bom1-2.cdninstagram.com/vp/5f...
# 45  https://scontent-bom1-2.cdninstagram.com/vp/f0...
#
#     edge_media_preview_like  comments_disabled  edge_media_to_comment  \
# 6                        61                  1                      2
# 7                        28                  0                      0
# 8                        20                  1                      1
# 9                        15                  1                      1
# 10                       16                  1                      0
# 12                       31                  1                      0
# 15                        4                  1                      0
# 16                       17                  1                      1
# 17                        8                  1                      0
# 29                       10                  1                      0
# 30                       16                  1                      0
# 34                        3                  1                      0
# 35                        2                  1                      0
# 37                        2                  1                      0
# 38                        3                  1                      0
# 39                        1                  1                      0
# 40                        3                  1                      0
# 41                        6                  1                      0
# 42                        3                  1                      0
# 43                        6                  1                      0
# 45                        3                  1                      0
#
#     dimensions_height  dimensions_width  \
# 6                 640               640
# 7                 750               750
# 8                1080              1080
# 9                1080              1080
# 10               1080              1080
# 12                480               480
# 15               1080              1080
# 16               1349              1080
# 17               1080              1080
# 29               1080              1080
# 30               1350              1080
# 34                640               640
# 35                640               640
# 37                640               640
# 38                640               640
# 39                640               640
# 40                640               640
# 41                640               640
# 42                640               640
# 43                640               640
# 45                640               640
#
#                                 edge_media_to_caption  \
# 6   Innovative Robotics for Schools: Strategies to...
# 7                           #roboticseminar #robotics
# 8      #internationalrobotolympid #20thIRO  #robotics
# 9                  #robotics #dstc #sembreak #sumobot
# 10     #robotics #sumobot #sembreak #dstc #robotics #
# 12  Great things start from small beginnings... Ma...
# 15   #DSTCSummerRobotics2017 #DSTCSummerSumoGames2017
# 16  #DSTCSummerRobotics2017 #summersumogames2017 #...
# 17  #DSTCSummerSumoGames2017\n#DSTCSummerRobotics2...
# 29        #deped #k12nstf #depednstf #pinoyrobotgames
# 30  #taiwaneducation #studyfun #teacherstraining #k12
# 34                    haha party #tgif #friday night!
# 35                                   Hello #July ! :)
# 37  #brother #sister #sibling loveee! <3 😁😘😍 have ...
# 38                              Good Morning!:) #qotd
# 39                    boys in action! #school #robots
# 40                                 #tgif everyone! :)
# 41  Get your own personalized printer now! :) #pri...
# 42                               #happyfathersday !:)
# 43           Robots? #ironman #happyindependenceday !
# 45   ready for #game3 ? it's game time!! #nba #finals
#
#                                                  tags  taken_at_timestamp  \
# 6   'pornstar', 'robot', 'robotics', 'dstc', 'robo...          1517367046
# 7                        'roboticseminar', 'robotics'          1516005877
# 8   '20thIRO', 'robotics', 'internationalrobotolym...          1516005690
# 9           'robotics', 'dstc', 'sembreak', 'sumobot'          1509018933
# 10          'robotics', 'dstc', 'sembreak', 'sumobot'          1509018898
# 12  'robotgames', 'robotics', 'dstc', 'inexrobots'...          1507392618
# 15  'DSTCSummerRobotics2017', 'DSTCSummerSumoGames...          1489379765
# 16  'roboticsworkshop2017', 'sumobotcompetition', ...          1489378867
# 17  'summer2017goals', 'roboticsworkshop2017', 'su...          1489378639
# 29  'deped', 'k12nstf', 'depednstf', 'pinoyrobotga...          1484644212
# 30  'studyfun', 'k12', 'teacherstraining', 'taiwan...          1484644089
# 34                                   'friday', 'tgif'          1404472500
# 35                                             'July'          1404199395
# 37                     'brother', 'sibling', 'sister'          1403920987
# 38                                             'qotd'          1403741158
# 39                                 'robots', 'school'          1403512321
# 40                                             'tgif'          1403261985
# 41              'printer', 'philippines', '3dprinter'          1403223091
# 42                                  'happyfathersday'          1402794431
# 43                  'ironman', 'happyindependenceday'          1402546843
# 45                           'finals', 'nba', 'game3'          1402451483
#
#     shareable
# 6           0
# 7           0
# 8           1
# 9           1
# 10          1
# 12          1
# 15          1
# 16          1
# 17          1
# 29          1
# 30          1
# 34          1
# 35          1
# 37          1
# 38          1
# 39          1
# 40          1
# 41          1
# 42          1
# 43          1
# 45          1
