# %%
import pandas as pd
import numpy as np
df=pd.read_csv('dataset.csv',encoding='utf8')
#df['tags']=df['tags'].apply(lambda x: x.length()>0)
#df[df['tags'].map(len)>0]
#df['tgas']=df['tgas'].tolist()
#df['tagslist'] = [','.join(map(str, l)) for l in df['tags']]
df = df[pd.notnull(df['tags'])]
df = df[pd.notnull(df['comments_disabled'])]
df=df.loc[df['comments_disabled']=='FALSE']
df=df[df['tags'].apply(lambda x: len(x) > 2)]
df['tags']=df['tags'].apply(lambda x: x[1:-1])
print(len(df['tags']))
df
# Out:
# 3233
#         shortcode         username  \
# 75    BzGac4QFKaW  adventurouskate
# 76    BzD_vbnF9Mo  adventurouskate
# 77    By-qWWUlEGa  adventurouskate
# 78    By8EdJAFY2B  adventurouskate
# 79    By5gXhTl7v3  adventurouskate
# 80    By20sKhl0CI  adventurouskate
# 81    By0ZzixlhMS  adventurouskate
# 82    Byx-69hFVbC  adventurouskate
# 83    ByvHtHSljM9  adventurouskate
# 84    BysWU5xF4tQ  adventurouskate
# 85    Byp7bZ-FfPt  adventurouskate
# 87    Bykwm5FFkAk  adventurouskate
# 88    ByiRXalFwpK  adventurouskate
# 89    ByfpBWSl8B3  adventurouskate
# 90    BydG_p8FQ9g  adventurouskate
# 91    Byak7M-F1Qk  adventurouskate
# 92    ByX-e35FdG2  adventurouskate
# 93    ByVUn3Klwk0  adventurouskate
# 94    BySusaCFboA  adventurouskate
# 95    ByQPKfAF3ST  adventurouskate
# 96    ByNmdLnltTD  adventurouskate
# 98    ByF8c-0l1q4  adventurouskate
# 99    ByDXN_NgWs4  adventurouskate
# 100   ByBAzjFFftd  adventurouskate
# 101   Bx8Kxf9l786  adventurouskate
# 103   Bx21AYLlWeb  adventurouskate
# 105   BxxVhWUF2Ui  adventurouskate
# 106   BxsFIX5FOiQ  adventurouskate
# 107   Bxk31-KFE2d  adventurouskate
# 108   BxiENZqlcHU  adventurouskate
# ...           ...              ...
# 6155  BxRHVm7g9Tx    walkwithindia
# 6156  BxRGWEXAyQF    walkwithindia
# 6158  BxO3f0Ug27Z    walkwithindia
# 6159  BxOd9z7Ahbq    walkwithindia
# 6160  BxObAk6gNPi    walkwithindia
# 6161  BxMPQx2AF78    walkwithindia
# 6162  BxJc7PaAKJ5    walkwithindia
# 6163  BxFrXdSgz1G    walkwithindia
# 6164  BxEmkdGgneQ    walkwithindia
# 6165  BxEmAbSA22D    walkwithindia
# 6166  BxEfnvHA5p-    walkwithindia
# 6167  BxCFk_0AZdb    walkwithindia
# 6168  BxCEgqegMu8    walkwithindia
# 6170  BxBlm9JgDNM    walkwithindia
# 6171  BxBkTGfgIwl    walkwithindia
# 6173  BxAAl7KAj2F    walkwithindia
# 6174  BxAATytgQ_9    walkwithindia
# 6175  Bw_cNzRA_E2    walkwithindia
# 6176  Bw_atJQAEdN    walkwithindia
# 6177  Bw_aOG2A1_F    walkwithindia
# 6178  Bw848EEgz7i    walkwithindia
# 6179  Bw80LlYg_qB    walkwithindia
# 6180  Bw8ySWFgFI5    walkwithindia
# 6181  Bw8vMrQAfqT    walkwithindia
# 6182  Bw6PEdhgyhp    walkwithindia
# 6183  Bw3pE_8A7XL    walkwithindia
# 6184  BwzUwJDAcIn    walkwithindia
# 6185  BwzSrynAPpd    walkwithindia
# 6186  BwzJ_rtgktD    walkwithindia
# 6189  Bu8jhPDBq9b      yourfoodlab
#
#                                             display_url  \
# 75    https://scontent-bom1-2.cdninstagram.com/vp/e5...
# 76    https://scontent-bom1-2.cdninstagram.com/vp/9e...
# 77    https://scontent-bom1-2.cdninstagram.com/vp/01...
# 78    https://scontent-bom1-2.cdninstagram.com/vp/2c...
# 79    https://scontent-bom1-2.cdninstagram.com/vp/86...
# 80    https://scontent-bom1-2.cdninstagram.com/vp/7a...
# 81    https://scontent-bom1-2.cdninstagram.com/vp/67...
# 82    https://scontent-bom1-2.cdninstagram.com/vp/a1...
# 83    https://scontent-bom1-2.cdninstagram.com/vp/06...
# 84    https://scontent-bom1-2.cdninstagram.com/vp/b7...
# 85    https://scontent-bom1-2.cdninstagram.com/vp/26...
# 87    https://scontent-bom1-2.cdninstagram.com/vp/d7...
# 88    https://scontent-bom1-2.cdninstagram.com/vp/83...
# 89    https://scontent-bom1-2.cdninstagram.com/vp/76...
# 90    https://scontent-bom1-2.cdninstagram.com/vp/95...
# 91    https://scontent-bom1-2.cdninstagram.com/vp/72...
# 92    https://scontent-bom1-2.cdninstagram.com/vp/e4...
# 93    https://scontent-bom1-2.cdninstagram.com/vp/fc...
# 94    https://scontent-bom1-2.cdninstagram.com/vp/6b...
# 95    https://scontent-bom1-2.cdninstagram.com/vp/19...
# 96    https://scontent-bom1-2.cdninstagram.com/vp/d8...
# 98    https://scontent-bom1-2.cdninstagram.com/vp/de...
# 99    https://scontent-bom1-2.cdninstagram.com/vp/6a...
# 100   https://scontent-bom1-2.cdninstagram.com/vp/85...
# 101   https://scontent-bom1-2.cdninstagram.com/vp/70...
# 103   https://scontent-bom1-2.cdninstagram.com/vp/b2...
# 105   https://scontent-bom1-2.cdninstagram.com/vp/e9...
# 106   https://scontent-bom1-2.cdninstagram.com/vp/1a...
# 107   https://scontent-bom1-2.cdninstagram.com/vp/2c...
# 108   https://scontent-bom1-2.cdninstagram.com/vp/07...
# ...                                                 ...
# 6155  https://scontent-bom1-2.cdninstagram.com/vp/be...
# 6156  https://scontent-bom1-2.cdninstagram.com/vp/b7...
# 6158  https://scontent-bom1-2.cdninstagram.com/vp/29...
# 6159  https://scontent-bom1-2.cdninstagram.com/vp/fd...
# 6160  https://scontent-bom1-2.cdninstagram.com/vp/22...
# 6161  https://scontent-bom1-2.cdninstagram.com/vp/97...
# 6162  https://scontent-bom1-2.cdninstagram.com/vp/ce...
# 6163  https://scontent-bom1-2.cdninstagram.com/vp/60...
# 6164  https://scontent-bom1-2.cdninstagram.com/vp/29...
# 6165  https://scontent-bom1-2.cdninstagram.com/vp/de...
# 6166  https://scontent-bom1-2.cdninstagram.com/vp/37...
# 6167  https://scontent-bom1-2.cdninstagram.com/vp/f1...
# 6168  https://scontent-bom1-2.cdninstagram.com/vp/6e...
# 6170  https://scontent-bom1-2.cdninstagram.com/vp/2a...
# 6171  https://scontent-bom1-2.cdninstagram.com/vp/ac...
# 6173  https://scontent-bom1-2.cdninstagram.com/vp/fb...
# 6174  https://scontent-bom1-2.cdninstagram.com/vp/ff...
# 6175  https://scontent-bom1-2.cdninstagram.com/vp/a3...
# 6176  https://scontent-bom1-2.cdninstagram.com/vp/c5...
# 6177  https://scontent-bom1-2.cdninstagram.com/vp/0d...
# 6178  https://scontent-bom1-2.cdninstagram.com/vp/be...
# 6179  https://scontent-bom1-2.cdninstagram.com/vp/d0...
# 6180  https://scontent-bom1-2.cdninstagram.com/vp/76...
# 6181  https://scontent-bom1-2.cdninstagram.com/vp/e8...
# 6182  https://scontent-bom1-2.cdninstagram.com/vp/6a...
# 6183  https://scontent-bom1-2.cdninstagram.com/vp/de...
# 6184  https://scontent-bom1-2.cdninstagram.com/vp/3c...
# 6185  https://scontent-bom1-2.cdninstagram.com/vp/91...
# 6186  https://scontent-bom1-2.cdninstagram.com/vp/7e...
# 6189  https://scontent-bom1-2.cdninstagram.com/vp/96...
#
#      edge_media_preview_like comments_disabled edge_media_to_comment  \
# 75                       533             FALSE                    12
# 76                      1360             FALSE                    54
# 77                       883             FALSE                    52
# 78                       942             FALSE                    40
# 79                       892             FALSE                    35
# 80                       742             FALSE                    26
# 81                       831             FALSE                    27
# 82                       972             FALSE                    56
# 83                      1158             FALSE                    63
# 84                       791             FALSE                    44
# 85                      1121             FALSE                    38
# 87                       878             FALSE                    25
# 88                       580             FALSE                    15
# 89                       784             FALSE                    53
# 90                      1064             FALSE                    25
# 91                      1038             FALSE                    29
# 92                       990             FALSE                    25
# 93                      1767             FALSE                    88
# 94                       931             FALSE                    66
# 95                      1584             FALSE                    97
# 96                      1018             FALSE                    27
# 98                       780             FALSE                    41
# 99                       891             FALSE                    25
# 100                      921             FALSE                    59
# 101                      733             FALSE                    13
# 103                      762             FALSE                    69
# 105                      799             FALSE                    23
# 106                     1321             FALSE                    81
# 107                      793             FALSE                    21
# 108                      657             FALSE                    22
# ...                      ...               ...                   ...
# 6155                    6883             FALSE                    10
# 6156                    5171             FALSE                    12
# 6158                    6314             FALSE                     9
# 6159                    6145             FALSE                    37
# 6160                   10458             FALSE                    31
# 6161                    4108             FALSE                     3
# 6162                   12260             FALSE                    77
# 6163                    5976             FALSE                    43
# 6164                   21933             FALSE                   331
# 6165                   10744             FALSE                    38
# 6166                    8714             FALSE                    96
# 6167                   10199             FALSE                    22
# 6168                    4697             FALSE                     5
# 6170                    5813             FALSE                    10
# 6171                    5305             FALSE                    18
# 6173                    5836             FALSE                    34
# 6174                    4172             FALSE                     7
# 6175                    4710             FALSE                     6
# 6176                    4669             FALSE                     6
# 6177                    7531             FALSE                    28
# 6178                    6442             FALSE                    10
# 6179                    9105             FALSE                    33
# 6180                    6047             FALSE                     4
# 6181                    3629             FALSE                    11
# 6182                    8170             FALSE                    10
# 6183                    6467             FALSE                    23
# 6184                    4081             FALSE                    11
# 6185                    3512             FALSE                     4
# 6186                    4657             FALSE                    20
# 6189                    4278             FALSE                     8
#
#      dimensions_height dimensions_width  \
# 75                 720             1080
# 76                1189             1080
# 77                1350             1080
# 78                1350             1080
# 79                 724             1080
# 80                1270             1080
# 81                 836             1080
# 82                1350             1080
# 83                 749             1080
# 84                1350             1080
# 85                1332             1080
# 87                 949             1080
# 88                 749             1080
# 89                 998             1080
# 90                1344             1080
# 91                 789             1080
# 92                 787             1080
# 93                1350             1080
# 94                 810             1080
# 95                1182             1080
# 96                1350             1080
# 98                1349             1080
# 99                1350             1080
# 100                766             1080
# 101               1080             1080
# 103                715             1080
# 105                724             1080
# 106               1321             1080
# 107               1350             1080
# 108               1349             1080
# ...                ...              ...
# 6155              1321             1080
# 6156               750              750
# 6158              1266             1080
# 6159              1220             1080
# 6160              1278             1080
# 6161               737              750
# 6162              1304             1080
# 6163              1298             1080
# 6164              1328             1080
# 6165               750              750
# 6166               750              750
# 6167              1296             1080
# 6168               750              750
# 6170              1349             1080
# 6171               750              750
# 6173              1325             1080
# 6174              1331             1080
# 6175              1295             1080
# 6176              1290             1080
# 6177              1321             1080
# 6178              1284             1080
# 6179              1350             1080
# 6180              1189             1080
# 6181              1323             1080
# 6182              1316             1080
# 6183              1322             1080
# 6184              1335             1080
# 6185              1334             1080
# 6186              1207             1080
# 6189              1350             1080
#
#                                   edge_media_to_caption  \
# 75    ??THE HILLS ARE ALIIIIIIIVE ?? Can you believe...
# 76    I am home, home, home. ?? Three weeks in #Ital...
# 77    Say hey to your gargoyle for me. ?? The first ...
# 78    Is it true that #Milan is a fashionable town? ...
# 79    Train life. ?? Trains are my favorite way to t...
# 80    This is the best chocolatey beverage you�ve ne...
# 81    Everything on Instagram is insanely posed, but...
# 82    #ThisIs34. ?? I�m in the closing months of bei...
# 83    Everyone is familiar with Lake Como, but there...
# 84    Confession time � ever used #Tinder on your tr...
# 85    The #Dolomites really do deliver. ? For my fin...
# 87    The #Dolomites are MAGICAL. ? Today I went on ...
# 88    Hello #Dolomites! ?? After the insanity of #Tr...
# 89    What are your feelings on...gelato? ?? When I ...
# 90    Romance on #LakeGarda. ?? My little excursion ...
# 91    #Trentino, you are SO pretty � even when you m...
# 92    Greetings from #Trentino, #Italy! How gorgeous...
# 93    Every time I go to #Italy, without failure, I ...
# 94    Greetings from #Florence, #Italy! ?? What a tr...
# 95    Did you know that #Bologna is the best food ci...
# 96    What happens when a city you love � BOLOGNA, I...
# 98    Have you ever been to the #Highline before? Th...
# 99    FASHION. ?????? I loved this @dereklam dress s...
# 100   I used to think I was a beach person. Nope. I�...
# 101   Kicking off summer in #Bushwick. ?? I have two...
# 103   I am in hardcore ITALY planning mode! ???? A w...
# 105   Sometimes a sunset can be a REALLY pink sunset...
# 106   Weird question � do you guys remember �Sharon,...
# 107   I should totally try to sell this pineapple pi...
# 108   Champagne, plunge pool, sittin� in a birdcage....
# ...                                                 ...
# 6155  Peacock on lovely morning drive\r\r\n @harsha_...
# 6156  Mini Tiffin 😋 perfect breakfast ? \r\r\n@thamb...
# 6158  Lassi 😍❤️ summer essentials 😋\r\r\n@petukkolka...
# 6159  TAG A DOSA LOVER ❤️\r\r\n@thetravellingbeee \r...
# 6160  Located amidst imposing mountains in Karnataka...
# 6161  Boston cream pie - 2 layers of soft vanilla ca...
# 6162  “READ THE CAPTION“ do you agree on this ? 💁‍♂️...
# 6163  Tag a friend ❤️ who else is craving for someth...
# 6164  Tag your SQUAD! 👬👫\r\r\nVisapur Fort (also cal...
# 6165  Such a mouth watering pic of jamun! 😋 tag some...
# 6166  Tag a rose milk lover! 🙋🏼‍♂️ @foodtalk_chennai...
# 6167  Border of Goa & Karnataka, India\r\r\nCredits ...
# 6168  Mango Lassi❣️😋\r\r\n@streets_to_savories \r\r\...
# 6170  If you truly love nature, you will find beauty...
# 6171  Tag a Friend ❤️ tell us what’s your favourite ...
# 6173  The statue of Unity!! tag a friend. \r\r\n#wal...
# 6174  Chilli cheese maggi from @cafe_central_tnagar ...
# 6175  It's that time of year again where we welcome ...
# 6176  Wayanad, the green paradise is nestled among t...
# 6177  Tag a friend and make them crave for this heal...
# 6178  Beat the heat\r\r\nCredits @myvellore\r\r\n.\r...
# 6179  Info park kochi\r\r\nCredits @jerin.sebastian ...
# 6180  People say EAT TO LIVE\r\r\nWe say LIVE TO EAT...
# 6181  SUMMER VIBES 😬 \r\r\n@jaipur_holic .\r\r\n.\r\...
# 6182  Inner Peace! ( lord shiva) on the banks in Gan...
# 6183  Summers are here😓 What's your pick? Left or Ri...
# 6184  curly.tales\r\r\nUnicorns are real!\r\r\nThis ...
# 6185  Did you know that India's tallest building is ...
# 6186  Tag a friend ❤️ Caramel Brownie 🙌🏻\r\r\n@succu...
# 6189  Mutton Kheema Ghotala\r\r\n\r\r\nHave you guys...
#
#                                                    tags taken_at_timestamp
# 75      'Italy', 'southtyrol', 'dolomites', 'AltoAdige'         1561395835
# 76                                  'Italy', 'Florence'         1561314723
# 77                                              'Milan'         1561135735
# 78                                     'Italy', 'Milan'         1561048759
# 79                              'Frecciarossa', 'Italy'         1560962730
# 80                         'bicerin', 'Torino', 'italy'         1560872721
# 81    'piemonte', 'italia', 'photographerlife', 'Mot...         1560791517
# 82                                           'ThisIs34'         1560710313
# 83    'Italy', 'piemonte', 'LakeMaggiore', 'lagodima...         1560614255
# 84                                             'Tinder'         1560521258
# 85    'italia', 'SouthTyrol', 'altoadige', 'Dolomite...         1560440046
# 87                                          'Dolomites'         1560266601
# 88    'Italy', 'SouthTyrol', 'Dolomites', 'Traverse1...         1560183112
# 89     'Trento', 'visittrentino', 'Italy', 'Traverse19'         1560094851
# 90    'Trentino', 'Italy', 'LakeGarda', 'RivaDelGard...         1560009903
# 91    'Trentino', 'LakeGarda', 'visittrentino', 'Riv...         1559924932
# 92    'Trentino', 'Italy', 'visittrentino', 'Trento'...         1559837668
# 93                         'Vespa', 'Italy', 'Florence'         1559748612
# 94                                  'Italy', 'Florence'         1559661618
# 95    'Bologna', 'Italy', 'Blogville', 'EmiliaRomagn...         1559577978
# 96                         'Bologna', 'inEmiliaRomagna'         1559489527
# 98                           'Highline', 'HighlineSpur'         1559232624
# 99          'NYC', 'newyorklife', 'yellowdress', 'Soho'         1559145994
# 100                                  'Vail', 'Colorado'         1559067134
# 101                                          'Bushwick'         1558904588
# 103                                             'Italy'         1558725403
# 105   'loveantiguabarbuda', 'whatcoollookslike', 'An...         1558541124
# 106   'LoveAntiguaBarbuda', 'whatcoollookslike', 'An...         1558364758
# 107   'loveantiguabarbuda', 'whatcoollookslike', 'An...         1558122911
# 108   'loveantiguabarbuda', 'whatcoollookslike', 'An...         1558028731
# ...                                                 ...                ...
# 6155  'sunray', 'sunrays', 'earthcapture', 'bbcwildl...         1557459946
# 6156                         'walkwithindia', 'chennai'         1557459425
# 6158                                    'walkwithindia'         1557384532
# 6159  'southindianfood', 'chennaifoodie', 'chennai',...         1557371146
# 6160  'nammakarnatakaphotographers', 'karnatakafocus...         1557369596
# 6161                                    'walkwithindia'         1557296328
# 6162  'rajasthan', 'indiapictures', 'shiva', 'harhar...         1557202829
# 6163  'indianbreakfast', 'indianrecipes', 'indianfoo...         1557076182
# 6164  'mumbai', 'india_ig', 'travelgram', 'instagood...         1557040113
# 6165                                    'walkwithindia'         1557039818
# 6166                                    'walkwithindia'         1557036470
# 6167  'fromwhereidrone', 'goa', 'watchthisinstagood'...         1556955707
# 6168             'lassi', 'indianfood', 'Walkwithindia'         1556955147
# 6170                                    'walkwithindia'         1556938946
# 6171                'india', 'walkwithindia', 'chennai'         1556938259
# 6173                                    'walkwithindia'         1556885984
# 6174                                    'walkwithindia'         1556885836
# 6175  'punefoodblogger', 'mango', 'livetoeat', 'food...         1556866912
# 6176  'keralam', 'wayanad', 'mypixeldiary', 'indianp...         1556866120
# 6177  'Chennaites', 'ChennaiSummer', 'FreshJuice', '...         1556865866
# 6178  'cmcvellore', 'myvellore', 'tender', 'vellore'...         1556781308
# 6179  'skypixel', 'travelgram', 'bobbyjoshi', 'drone...         1556778814
# 6180                                    'walkwithindia'         1556777820
# 6181  'mumbaiblogger', 'foodblogger', 'pastalove', '...         1556776201
# 6182  'lordshiva', 'walkwithindia', 'incredibleindia...         1556692248
# 6183  'delhistreetfood', 'foodblogger', 'illgrammer'...         1556605220
# 6184  'foodgoals', 'foodblogger', 'igfood', 'yummy',...         1556460346
# 6185  'Kolkatagram', 'kolkatadiaries', 'Calcutta', '...         1556459262
# 6186                  'foodietribe', 'eastcoastfoodies'         1556454706
# 6189  'foodporn', 'foodislife', 'foodie', 'indiancui...         1552475111
#
# [3233 rows x 11 columns]

# %%
dkeys=df['shortcode'].tolist()
dtags=df['tags'].tolist()
dtags=[x.split(', ') for x in dtags]
empty=[]
for i in dtags:
    x=[q[1:-1] for q in i]
    empty.append(x)
dtags=empty
#print(empty)
#if empty[0][0]=='roboticseminar':
#    print('done')

#print(taga[0][0][1:-1])
#taga[0][0]
#d={}
#q=len(kiys)
mydict = dict(zip(dkeys, dtags))
#print(mydict)


#mydict['BemQM09A0qL']=1
#print(mydict)
stopwords = [line.rstrip('\n') for line in open('stopwords.txt')]

stopwords=stopwords[0].split(' ')
#print(stopwords)
shareable={}
for i in mydict:
    shareable[i]=1
    temp=list(mydict[i])
    #print(temp)
    #break
    #temp=['robot']
    flag=False
    for x in temp:
        #print(temp)
        for st in stopwords:
            #print(st,x)
            if(x==st):
                shareable[i]=0
                flag=True
                break;
        if flag==True:
            break;
sharing=[shareable[i] for i in shareable]

#df["comments_disabled"]=df["comments_disabled"].replace({False:0,True:1})

df['shareable']=sharing

#df['shareable']=df['shareable']*df['comments_disabled']
df=df.loc[df['shareable']==1]

df
# Out:
#         shortcode         username  \
# 75    BzGac4QFKaW  adventurouskate
# 76    BzD_vbnF9Mo  adventurouskate
# 77    By-qWWUlEGa  adventurouskate
# 78    By8EdJAFY2B  adventurouskate
# 79    By5gXhTl7v3  adventurouskate
# 80    By20sKhl0CI  adventurouskate
# 81    By0ZzixlhMS  adventurouskate
# 82    Byx-69hFVbC  adventurouskate
# 83    ByvHtHSljM9  adventurouskate
# 84    BysWU5xF4tQ  adventurouskate
# 85    Byp7bZ-FfPt  adventurouskate
# 87    Bykwm5FFkAk  adventurouskate
# 88    ByiRXalFwpK  adventurouskate
# 89    ByfpBWSl8B3  adventurouskate
# 90    BydG_p8FQ9g  adventurouskate
# 91    Byak7M-F1Qk  adventurouskate
# 92    ByX-e35FdG2  adventurouskate
# 93    ByVUn3Klwk0  adventurouskate
# 94    BySusaCFboA  adventurouskate
# 95    ByQPKfAF3ST  adventurouskate
# 96    ByNmdLnltTD  adventurouskate
# 98    ByF8c-0l1q4  adventurouskate
# 99    ByDXN_NgWs4  adventurouskate
# 100   ByBAzjFFftd  adventurouskate
# 101   Bx8Kxf9l786  adventurouskate
# 103   Bx21AYLlWeb  adventurouskate
# 105   BxxVhWUF2Ui  adventurouskate
# 106   BxsFIX5FOiQ  adventurouskate
# 107   Bxk31-KFE2d  adventurouskate
# 108   BxiENZqlcHU  adventurouskate
# ...           ...              ...
# 6155  BxRHVm7g9Tx    walkwithindia
# 6156  BxRGWEXAyQF    walkwithindia
# 6158  BxO3f0Ug27Z    walkwithindia
# 6159  BxOd9z7Ahbq    walkwithindia
# 6160  BxObAk6gNPi    walkwithindia
# 6161  BxMPQx2AF78    walkwithindia
# 6162  BxJc7PaAKJ5    walkwithindia
# 6163  BxFrXdSgz1G    walkwithindia
# 6164  BxEmkdGgneQ    walkwithindia
# 6165  BxEmAbSA22D    walkwithindia
# 6166  BxEfnvHA5p-    walkwithindia
# 6167  BxCFk_0AZdb    walkwithindia
# 6168  BxCEgqegMu8    walkwithindia
# 6170  BxBlm9JgDNM    walkwithindia
# 6171  BxBkTGfgIwl    walkwithindia
# 6173  BxAAl7KAj2F    walkwithindia
# 6174  BxAATytgQ_9    walkwithindia
# 6175  Bw_cNzRA_E2    walkwithindia
# 6176  Bw_atJQAEdN    walkwithindia
# 6177  Bw_aOG2A1_F    walkwithindia
# 6178  Bw848EEgz7i    walkwithindia
# 6179  Bw80LlYg_qB    walkwithindia
# 6180  Bw8ySWFgFI5    walkwithindia
# 6181  Bw8vMrQAfqT    walkwithindia
# 6182  Bw6PEdhgyhp    walkwithindia
# 6183  Bw3pE_8A7XL    walkwithindia
# 6184  BwzUwJDAcIn    walkwithindia
# 6185  BwzSrynAPpd    walkwithindia
# 6186  BwzJ_rtgktD    walkwithindia
# 6189  Bu8jhPDBq9b      yourfoodlab
#
#                                             display_url  \
# 75    https://scontent-bom1-2.cdninstagram.com/vp/e5...
# 76    https://scontent-bom1-2.cdninstagram.com/vp/9e...
# 77    https://scontent-bom1-2.cdninstagram.com/vp/01...
# 78    https://scontent-bom1-2.cdninstagram.com/vp/2c...
# 79    https://scontent-bom1-2.cdninstagram.com/vp/86...
# 80    https://scontent-bom1-2.cdninstagram.com/vp/7a...
# 81    https://scontent-bom1-2.cdninstagram.com/vp/67...
# 82    https://scontent-bom1-2.cdninstagram.com/vp/a1...
# 83    https://scontent-bom1-2.cdninstagram.com/vp/06...
# 84    https://scontent-bom1-2.cdninstagram.com/vp/b7...
# 85    https://scontent-bom1-2.cdninstagram.com/vp/26...
# 87    https://scontent-bom1-2.cdninstagram.com/vp/d7...
# 88    https://scontent-bom1-2.cdninstagram.com/vp/83...
# 89    https://scontent-bom1-2.cdninstagram.com/vp/76...
# 90    https://scontent-bom1-2.cdninstagram.com/vp/95...
# 91    https://scontent-bom1-2.cdninstagram.com/vp/72...
# 92    https://scontent-bom1-2.cdninstagram.com/vp/e4...
# 93    https://scontent-bom1-2.cdninstagram.com/vp/fc...
# 94    https://scontent-bom1-2.cdninstagram.com/vp/6b...
# 95    https://scontent-bom1-2.cdninstagram.com/vp/19...
# 96    https://scontent-bom1-2.cdninstagram.com/vp/d8...
# 98    https://scontent-bom1-2.cdninstagram.com/vp/de...
# 99    https://scontent-bom1-2.cdninstagram.com/vp/6a...
# 100   https://scontent-bom1-2.cdninstagram.com/vp/85...
# 101   https://scontent-bom1-2.cdninstagram.com/vp/70...
# 103   https://scontent-bom1-2.cdninstagram.com/vp/b2...
# 105   https://scontent-bom1-2.cdninstagram.com/vp/e9...
# 106   https://scontent-bom1-2.cdninstagram.com/vp/1a...
# 107   https://scontent-bom1-2.cdninstagram.com/vp/2c...
# 108   https://scontent-bom1-2.cdninstagram.com/vp/07...
# ...                                                 ...
# 6155  https://scontent-bom1-2.cdninstagram.com/vp/be...
# 6156  https://scontent-bom1-2.cdninstagram.com/vp/b7...
# 6158  https://scontent-bom1-2.cdninstagram.com/vp/29...
# 6159  https://scontent-bom1-2.cdninstagram.com/vp/fd...
# 6160  https://scontent-bom1-2.cdninstagram.com/vp/22...
# 6161  https://scontent-bom1-2.cdninstagram.com/vp/97...
# 6162  https://scontent-bom1-2.cdninstagram.com/vp/ce...
# 6163  https://scontent-bom1-2.cdninstagram.com/vp/60...
# 6164  https://scontent-bom1-2.cdninstagram.com/vp/29...
# 6165  https://scontent-bom1-2.cdninstagram.com/vp/de...
# 6166  https://scontent-bom1-2.cdninstagram.com/vp/37...
# 6167  https://scontent-bom1-2.cdninstagram.com/vp/f1...
# 6168  https://scontent-bom1-2.cdninstagram.com/vp/6e...
# 6170  https://scontent-bom1-2.cdninstagram.com/vp/2a...
# 6171  https://scontent-bom1-2.cdninstagram.com/vp/ac...
# 6173  https://scontent-bom1-2.cdninstagram.com/vp/fb...
# 6174  https://scontent-bom1-2.cdninstagram.com/vp/ff...
# 6175  https://scontent-bom1-2.cdninstagram.com/vp/a3...
# 6176  https://scontent-bom1-2.cdninstagram.com/vp/c5...
# 6177  https://scontent-bom1-2.cdninstagram.com/vp/0d...
# 6178  https://scontent-bom1-2.cdninstagram.com/vp/be...
# 6179  https://scontent-bom1-2.cdninstagram.com/vp/d0...
# 6180  https://scontent-bom1-2.cdninstagram.com/vp/76...
# 6181  https://scontent-bom1-2.cdninstagram.com/vp/e8...
# 6182  https://scontent-bom1-2.cdninstagram.com/vp/6a...
# 6183  https://scontent-bom1-2.cdninstagram.com/vp/de...
# 6184  https://scontent-bom1-2.cdninstagram.com/vp/3c...
# 6185  https://scontent-bom1-2.cdninstagram.com/vp/91...
# 6186  https://scontent-bom1-2.cdninstagram.com/vp/7e...
# 6189  https://scontent-bom1-2.cdninstagram.com/vp/96...
#
#      edge_media_preview_like comments_disabled edge_media_to_comment  \
# 75                       533             FALSE                    12
# 76                      1360             FALSE                    54
# 77                       883             FALSE                    52
# 78                       942             FALSE                    40
# 79                       892             FALSE                    35
# 80                       742             FALSE                    26
# 81                       831             FALSE                    27
# 82                       972             FALSE                    56
# 83                      1158             FALSE                    63
# 84                       791             FALSE                    44
# 85                      1121             FALSE                    38
# 87                       878             FALSE                    25
# 88                       580             FALSE                    15
# 89                       784             FALSE                    53
# 90                      1064             FALSE                    25
# 91                      1038             FALSE                    29
# 92                       990             FALSE                    25
# 93                      1767             FALSE                    88
# 94                       931             FALSE                    66
# 95                      1584             FALSE                    97
# 96                      1018             FALSE                    27
# 98                       780             FALSE                    41
# 99                       891             FALSE                    25
# 100                      921             FALSE                    59
# 101                      733             FALSE                    13
# 103                      762             FALSE                    69
# 105                      799             FALSE                    23
# 106                     1321             FALSE                    81
# 107                      793             FALSE                    21
# 108                      657             FALSE                    22
# ...                      ...               ...                   ...
# 6155                    6883             FALSE                    10
# 6156                    5171             FALSE                    12
# 6158                    6314             FALSE                     9
# 6159                    6145             FALSE                    37
# 6160                   10458             FALSE                    31
# 6161                    4108             FALSE                     3
# 6162                   12260             FALSE                    77
# 6163                    5976             FALSE                    43
# 6164                   21933             FALSE                   331
# 6165                   10744             FALSE                    38
# 6166                    8714             FALSE                    96
# 6167                   10199             FALSE                    22
# 6168                    4697             FALSE                     5
# 6170                    5813             FALSE                    10
# 6171                    5305             FALSE                    18
# 6173                    5836             FALSE                    34
# 6174                    4172             FALSE                     7
# 6175                    4710             FALSE                     6
# 6176                    4669             FALSE                     6
# 6177                    7531             FALSE                    28
# 6178                    6442             FALSE                    10
# 6179                    9105             FALSE                    33
# 6180                    6047             FALSE                     4
# 6181                    3629             FALSE                    11
# 6182                    8170             FALSE                    10
# 6183                    6467             FALSE                    23
# 6184                    4081             FALSE                    11
# 6185                    3512             FALSE                     4
# 6186                    4657             FALSE                    20
# 6189                    4278             FALSE                     8
#
#      dimensions_height dimensions_width  \
# 75                 720             1080
# 76                1189             1080
# 77                1350             1080
# 78                1350             1080
# 79                 724             1080
# 80                1270             1080
# 81                 836             1080
# 82                1350             1080
# 83                 749             1080
# 84                1350             1080
# 85                1332             1080
# 87                 949             1080
# 88                 749             1080
# 89                 998             1080
# 90                1344             1080
# 91                 789             1080
# 92                 787             1080
# 93                1350             1080
# 94                 810             1080
# 95                1182             1080
# 96                1350             1080
# 98                1349             1080
# 99                1350             1080
# 100                766             1080
# 101               1080             1080
# 103                715             1080
# 105                724             1080
# 106               1321             1080
# 107               1350             1080
# 108               1349             1080
# ...                ...              ...
# 6155              1321             1080
# 6156               750              750
# 6158              1266             1080
# 6159              1220             1080
# 6160              1278             1080
# 6161               737              750
# 6162              1304             1080
# 6163              1298             1080
# 6164              1328             1080
# 6165               750              750
# 6166               750              750
# 6167              1296             1080
# 6168               750              750
# 6170              1349             1080
# 6171               750              750
# 6173              1325             1080
# 6174              1331             1080
# 6175              1295             1080
# 6176              1290             1080
# 6177              1321             1080
# 6178              1284             1080
# 6179              1350             1080
# 6180              1189             1080
# 6181              1323             1080
# 6182              1316             1080
# 6183              1322             1080
# 6184              1335             1080
# 6185              1334             1080
# 6186              1207             1080
# 6189              1350             1080
#
#                                   edge_media_to_caption  \
# 75    ??THE HILLS ARE ALIIIIIIIVE ?? Can you believe...
# 76    I am home, home, home. ?? Three weeks in #Ital...
# 77    Say hey to your gargoyle for me. ?? The first ...
# 78    Is it true that #Milan is a fashionable town? ...
# 79    Train life. ?? Trains are my favorite way to t...
# 80    This is the best chocolatey beverage you�ve ne...
# 81    Everything on Instagram is insanely posed, but...
# 82    #ThisIs34. ?? I�m in the closing months of bei...
# 83    Everyone is familiar with Lake Como, but there...
# 84    Confession time � ever used #Tinder on your tr...
# 85    The #Dolomites really do deliver. ? For my fin...
# 87    The #Dolomites are MAGICAL. ? Today I went on ...
# 88    Hello #Dolomites! ?? After the insanity of #Tr...
# 89    What are your feelings on...gelato? ?? When I ...
# 90    Romance on #LakeGarda. ?? My little excursion ...
# 91    #Trentino, you are SO pretty � even when you m...
# 92    Greetings from #Trentino, #Italy! How gorgeous...
# 93    Every time I go to #Italy, without failure, I ...
# 94    Greetings from #Florence, #Italy! ?? What a tr...
# 95    Did you know that #Bologna is the best food ci...
# 96    What happens when a city you love � BOLOGNA, I...
# 98    Have you ever been to the #Highline before? Th...
# 99    FASHION. ?????? I loved this @dereklam dress s...
# 100   I used to think I was a beach person. Nope. I�...
# 101   Kicking off summer in #Bushwick. ?? I have two...
# 103   I am in hardcore ITALY planning mode! ???? A w...
# 105   Sometimes a sunset can be a REALLY pink sunset...
# 106   Weird question � do you guys remember �Sharon,...
# 107   I should totally try to sell this pineapple pi...
# 108   Champagne, plunge pool, sittin� in a birdcage....
# ...                                                 ...
# 6155  Peacock on lovely morning drive\r\r\n @harsha_...
# 6156  Mini Tiffin 😋 perfect breakfast ? \r\r\n@thamb...
# 6158  Lassi 😍❤️ summer essentials 😋\r\r\n@petukkolka...
# 6159  TAG A DOSA LOVER ❤️\r\r\n@thetravellingbeee \r...
# 6160  Located amidst imposing mountains in Karnataka...
# 6161  Boston cream pie - 2 layers of soft vanilla ca...
# 6162  “READ THE CAPTION“ do you agree on this ? 💁‍♂️...
# 6163  Tag a friend ❤️ who else is craving for someth...
# 6164  Tag your SQUAD! 👬👫\r\r\nVisapur Fort (also cal...
# 6165  Such a mouth watering pic of jamun! 😋 tag some...
# 6166  Tag a rose milk lover! 🙋🏼‍♂️ @foodtalk_chennai...
# 6167  Border of Goa & Karnataka, India\r\r\nCredits ...
# 6168  Mango Lassi❣️😋\r\r\n@streets_to_savories \r\r\...
# 6170  If you truly love nature, you will find beauty...
# 6171  Tag a Friend ❤️ tell us what’s your favourite ...
# 6173  The statue of Unity!! tag a friend. \r\r\n#wal...
# 6174  Chilli cheese maggi from @cafe_central_tnagar ...
# 6175  It's that time of year again where we welcome ...
# 6176  Wayanad, the green paradise is nestled among t...
# 6177  Tag a friend and make them crave for this heal...
# 6178  Beat the heat\r\r\nCredits @myvellore\r\r\n.\r...
# 6179  Info park kochi\r\r\nCredits @jerin.sebastian ...
# 6180  People say EAT TO LIVE\r\r\nWe say LIVE TO EAT...
# 6181  SUMMER VIBES 😬 \r\r\n@jaipur_holic .\r\r\n.\r\...
# 6182  Inner Peace! ( lord shiva) on the banks in Gan...
# 6183  Summers are here😓 What's your pick? Left or Ri...
# 6184  curly.tales\r\r\nUnicorns are real!\r\r\nThis ...
# 6185  Did you know that India's tallest building is ...
# 6186  Tag a friend ❤️ Caramel Brownie 🙌🏻\r\r\n@succu...
# 6189  Mutton Kheema Ghotala\r\r\n\r\r\nHave you guys...
#
#                                                    tags taken_at_timestamp  \
# 75      'Italy', 'southtyrol', 'dolomites', 'AltoAdige'         1561395835
# 76                                  'Italy', 'Florence'         1561314723
# 77                                              'Milan'         1561135735
# 78                                     'Italy', 'Milan'         1561048759
# 79                              'Frecciarossa', 'Italy'         1560962730
# 80                         'bicerin', 'Torino', 'italy'         1560872721
# 81    'piemonte', 'italia', 'photographerlife', 'Mot...         1560791517
# 82                                           'ThisIs34'         1560710313
# 83    'Italy', 'piemonte', 'LakeMaggiore', 'lagodima...         1560614255
# 84                                             'Tinder'         1560521258
# 85    'italia', 'SouthTyrol', 'altoadige', 'Dolomite...         1560440046
# 87                                          'Dolomites'         1560266601
# 88    'Italy', 'SouthTyrol', 'Dolomites', 'Traverse1...         1560183112
# 89     'Trento', 'visittrentino', 'Italy', 'Traverse19'         1560094851
# 90    'Trentino', 'Italy', 'LakeGarda', 'RivaDelGard...         1560009903
# 91    'Trentino', 'LakeGarda', 'visittrentino', 'Riv...         1559924932
# 92    'Trentino', 'Italy', 'visittrentino', 'Trento'...         1559837668
# 93                         'Vespa', 'Italy', 'Florence'         1559748612
# 94                                  'Italy', 'Florence'         1559661618
# 95    'Bologna', 'Italy', 'Blogville', 'EmiliaRomagn...         1559577978
# 96                         'Bologna', 'inEmiliaRomagna'         1559489527
# 98                           'Highline', 'HighlineSpur'         1559232624
# 99          'NYC', 'newyorklife', 'yellowdress', 'Soho'         1559145994
# 100                                  'Vail', 'Colorado'         1559067134
# 101                                          'Bushwick'         1558904588
# 103                                             'Italy'         1558725403
# 105   'loveantiguabarbuda', 'whatcoollookslike', 'An...         1558541124
# 106   'LoveAntiguaBarbuda', 'whatcoollookslike', 'An...         1558364758
# 107   'loveantiguabarbuda', 'whatcoollookslike', 'An...         1558122911
# 108   'loveantiguabarbuda', 'whatcoollookslike', 'An...         1558028731
# ...                                                 ...                ...
# 6155  'sunray', 'sunrays', 'earthcapture', 'bbcwildl...         1557459946
# 6156                         'walkwithindia', 'chennai'         1557459425
# 6158                                    'walkwithindia'         1557384532
# 6159  'southindianfood', 'chennaifoodie', 'chennai',...         1557371146
# 6160  'nammakarnatakaphotographers', 'karnatakafocus...         1557369596
# 6161                                    'walkwithindia'         1557296328
# 6162  'rajasthan', 'indiapictures', 'shiva', 'harhar...         1557202829
# 6163  'indianbreakfast', 'indianrecipes', 'indianfoo...         1557076182
# 6164  'mumbai', 'india_ig', 'travelgram', 'instagood...         1557040113
# 6165                                    'walkwithindia'         1557039818
# 6166                                    'walkwithindia'         1557036470
# 6167  'fromwhereidrone', 'goa', 'watchthisinstagood'...         1556955707
# 6168             'lassi', 'indianfood', 'Walkwithindia'         1556955147
# 6170                                    'walkwithindia'         1556938946
# 6171                'india', 'walkwithindia', 'chennai'         1556938259
# 6173                                    'walkwithindia'         1556885984
# 6174                                    'walkwithindia'         1556885836
# 6175  'punefoodblogger', 'mango', 'livetoeat', 'food...         1556866912
# 6176  'keralam', 'wayanad', 'mypixeldiary', 'indianp...         1556866120
# 6177  'Chennaites', 'ChennaiSummer', 'FreshJuice', '...         1556865866
# 6178  'cmcvellore', 'myvellore', 'tender', 'vellore'...         1556781308
# 6179  'skypixel', 'travelgram', 'bobbyjoshi', 'drone...         1556778814
# 6180                                    'walkwithindia'         1556777820
# 6181  'mumbaiblogger', 'foodblogger', 'pastalove', '...         1556776201
# 6182  'lordshiva', 'walkwithindia', 'incredibleindia...         1556692248
# 6183  'delhistreetfood', 'foodblogger', 'illgrammer'...         1556605220
# 6184  'foodgoals', 'foodblogger', 'igfood', 'yummy',...         1556460346
# 6185  'Kolkatagram', 'kolkatadiaries', 'Calcutta', '...         1556459262
# 6186                  'foodietribe', 'eastcoastfoodies'         1556454706
# 6189  'foodporn', 'foodislife', 'foodie', 'indiancui...         1552475111
#
#       shareable
# 75            1
# 76            1
# 77            1
# 78            1
# 79            1
# 80            1
# 81            1
# 82            1
# 83            1
# 84            1
# 85            1
# 87            1
# 88            1
# 89            1
# 90            1
# 91            1
# 92            1
# 93            1
# 94            1
# 95            1
# 96            1
# 98            1
# 99            1
# 100           1
# 101           1
# 103           1
# 105           1
# 106           1
# 107           1
# 108           1
# ...         ...
# 6155          1
# 6156          1
# 6158          1
# 6159          1
# 6160          1
# 6161          1
# 6162          1
# 6163          1
# 6164          1
# 6165          1
# 6166          1
# 6167          1
# 6168          1
# 6170          1
# 6171          1
# 6173          1
# 6174          1
# 6175          1
# 6176          1
# 6177          1
# 6178          1
# 6179          1
# 6180          1
# 6181          1
# 6182          1
# 6183          1
# 6184          1
# 6185          1
# 6186          1
# 6189          1
#
# [3137 rows x 12 columns]

# %%
dkeys=df['shortcode'].tolist()
dtags=df['tags'].tolist()
dtags=[x.split(', ') for x in dtags]
empty=[]
for i in dtags:
    x=[q[1:-1] for q in i]
    empty.append(x)
dtags=empty
#print(empty)
#if empty[0][0]=='roboticseminar':
#    print('done')

#print(taga[0][0][1:-1])
#taga[0][0]
#d={}
#q=len(kiys)
mydict = dict(zip(dkeys, dtags))
#print(mydict)


popular_tags = [line.rstrip('\n') for line in open('Popular hashtags.txt')]

popular_tags=popular_tags[0].split(' ')
#to remove duplicates
popular_tags=list(dict.fromkeys(popular_tags))
#print(popular_tags)
popularity={}
for i in mydict:
    popularity[i]=0
    temp=list(mydict[i])
    for x in temp:
        #print(temp)
        for st in popular_tags:
            if(x==st):
                popularity[i]+=1
                break;
popular_hashtags=[popularity[i] for i in popularity]

df['popular_hashtags']=popular_hashtags
df=df.set_index('username')
df.to_csv(r'shareables.csv')
df
# Out:
#                  Unnamed: 0    shortcode  \
# username
# adventurouskate          75  BzGac4QFKaW
# adventurouskate          76  BzD_vbnF9Mo
# adventurouskate          77  By-qWWUlEGa
# adventurouskate          78  By8EdJAFY2B
# adventurouskate          79  By5gXhTl7v3
# adventurouskate          80  By20sKhl0CI
# adventurouskate          81  By0ZzixlhMS
# adventurouskate          82  Byx-69hFVbC
# adventurouskate          83  ByvHtHSljM9
# adventurouskate          84  BysWU5xF4tQ
# adventurouskate          85  Byp7bZ-FfPt
# adventurouskate          87  Bykwm5FFkAk
# adventurouskate          88  ByiRXalFwpK
# adventurouskate          89  ByfpBWSl8B3
# adventurouskate          90  BydG_p8FQ9g
# adventurouskate          91  Byak7M-F1Qk
# adventurouskate          92  ByX-e35FdG2
# adventurouskate          93  ByVUn3Klwk0
# adventurouskate          94  BySusaCFboA
# adventurouskate          95  ByQPKfAF3ST
# adventurouskate          96  ByNmdLnltTD
# adventurouskate          98  ByF8c-0l1q4
# adventurouskate          99  ByDXN_NgWs4
# adventurouskate         100  ByBAzjFFftd
# adventurouskate         101  Bx8Kxf9l786
# adventurouskate         103  Bx21AYLlWeb
# adventurouskate         105  BxxVhWUF2Ui
# adventurouskate         106  BxsFIX5FOiQ
# adventurouskate         107  Bxk31-KFE2d
# adventurouskate         108  BxiENZqlcHU
# ...                     ...          ...
# walkwithindia          6155  BxRHVm7g9Tx
# walkwithindia          6156  BxRGWEXAyQF
# walkwithindia          6158  BxO3f0Ug27Z
# walkwithindia          6159  BxOd9z7Ahbq
# walkwithindia          6160  BxObAk6gNPi
# walkwithindia          6161  BxMPQx2AF78
# walkwithindia          6162  BxJc7PaAKJ5
# walkwithindia          6163  BxFrXdSgz1G
# walkwithindia          6164  BxEmkdGgneQ
# walkwithindia          6165  BxEmAbSA22D
# walkwithindia          6166  BxEfnvHA5p-
# walkwithindia          6167  BxCFk_0AZdb
# walkwithindia          6168  BxCEgqegMu8
# walkwithindia          6170  BxBlm9JgDNM
# walkwithindia          6171  BxBkTGfgIwl
# walkwithindia          6173  BxAAl7KAj2F
# walkwithindia          6174  BxAATytgQ_9
# walkwithindia          6175  Bw_cNzRA_E2
# walkwithindia          6176  Bw_atJQAEdN
# walkwithindia          6177  Bw_aOG2A1_F
# walkwithindia          6178  Bw848EEgz7i
# walkwithindia          6179  Bw80LlYg_qB
# walkwithindia          6180  Bw8ySWFgFI5
# walkwithindia          6181  Bw8vMrQAfqT
# walkwithindia          6182  Bw6PEdhgyhp
# walkwithindia          6183  Bw3pE_8A7XL
# walkwithindia          6184  BwzUwJDAcIn
# walkwithindia          6185  BwzSrynAPpd
# walkwithindia          6186  BwzJ_rtgktD
# yourfoodlab            6189  Bu8jhPDBq9b
#
#                                                        display_url  \
# username
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/e5...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/9e...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/01...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/2c...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/86...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/7a...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/67...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/a1...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/06...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/b7...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/26...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/d7...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/83...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/76...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/95...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/72...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/e4...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/fc...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/6b...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/19...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/d8...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/de...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/6a...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/85...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/70...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/b2...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/e9...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/1a...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/2c...
# adventurouskate  https://scontent-bom1-2.cdninstagram.com/vp/07...
# ...                                                            ...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/be...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/b7...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/29...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/fd...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/22...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/97...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/ce...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/60...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/29...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/de...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/37...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/f1...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/6e...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/2a...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/ac...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/fb...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/ff...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/a3...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/c5...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/0d...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/be...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/d0...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/76...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/e8...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/6a...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/de...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/3c...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/91...
# walkwithindia    https://scontent-bom1-2.cdninstagram.com/vp/7e...
# yourfoodlab      https://scontent-bom1-2.cdninstagram.com/vp/96...
#
#                  edge_media_preview_like  comments_disabled  \
# username
# adventurouskate                      533              False
# adventurouskate                     1360              False
# adventurouskate                      883              False
# adventurouskate                      942              False
# adventurouskate                      892              False
# adventurouskate                      742              False
# adventurouskate                      831              False
# adventurouskate                      972              False
# adventurouskate                     1158              False
# adventurouskate                      791              False
# adventurouskate                     1121              False
# adventurouskate                      878              False
# adventurouskate                      580              False
# adventurouskate                      784              False
# adventurouskate                     1064              False
# adventurouskate                     1038              False
# adventurouskate                      990              False
# adventurouskate                     1767              False
# adventurouskate                      931              False
# adventurouskate                     1584              False
# adventurouskate                     1018              False
# adventurouskate                      780              False
# adventurouskate                      891              False
# adventurouskate                      921              False
# adventurouskate                      733              False
# adventurouskate                      762              False
# adventurouskate                      799              False
# adventurouskate                     1321              False
# adventurouskate                      793              False
# adventurouskate                      657              False
# ...                                  ...                ...
# walkwithindia                       6883              False
# walkwithindia                       5171              False
# walkwithindia                       6314              False
# walkwithindia                       6145              False
# walkwithindia                      10458              False
# walkwithindia                       4108              False
# walkwithindia                      12260              False
# walkwithindia                       5976              False
# walkwithindia                      21933              False
# walkwithindia                      10744              False
# walkwithindia                       8714              False
# walkwithindia                      10199              False
# walkwithindia                       4697              False
# walkwithindia                       5813              False
# walkwithindia                       5305              False
# walkwithindia                       5836              False
# walkwithindia                       4172              False
# walkwithindia                       4710              False
# walkwithindia                       4669              False
# walkwithindia                       7531              False
# walkwithindia                       6442              False
# walkwithindia                       9105              False
# walkwithindia                       6047              False
# walkwithindia                       3629              False
# walkwithindia                       8170              False
# walkwithindia                       6467              False
# walkwithindia                       4081              False
# walkwithindia                       3512              False
# walkwithindia                       4657              False
# yourfoodlab                         4278              False
#
#                  edge_media_to_comment  dimensions_height  dimensions_width  \
# username
# adventurouskate                     12                720              1080
# adventurouskate                     54               1189              1080
# adventurouskate                     52               1350              1080
# adventurouskate                     40               1350              1080
# adventurouskate                     35                724              1080
# adventurouskate                     26               1270              1080
# adventurouskate                     27                836              1080
# adventurouskate                     56               1350              1080
# adventurouskate                     63                749              1080
# adventurouskate                     44               1350              1080
# adventurouskate                     38               1332              1080
# adventurouskate                     25                949              1080
# adventurouskate                     15                749              1080
# adventurouskate                     53                998              1080
# adventurouskate                     25               1344              1080
# adventurouskate                     29                789              1080
# adventurouskate                     25                787              1080
# adventurouskate                     88               1350              1080
# adventurouskate                     66                810              1080
# adventurouskate                     97               1182              1080
# adventurouskate                     27               1350              1080
# adventurouskate                     41               1349              1080
# adventurouskate                     25               1350              1080
# adventurouskate                     59                766              1080
# adventurouskate                     13               1080              1080
# adventurouskate                     69                715              1080
# adventurouskate                     23                724              1080
# adventurouskate                     81               1321              1080
# adventurouskate                     21               1350              1080
# adventurouskate                     22               1349              1080
# ...                                ...                ...               ...
# walkwithindia                       10               1321              1080
# walkwithindia                       12                750               750
# walkwithindia                        9               1266              1080
# walkwithindia                       37               1220              1080
# walkwithindia                       31               1278              1080
# walkwithindia                        3                737               750
# walkwithindia                       77               1304              1080
# walkwithindia                       43               1298              1080
# walkwithindia                      331               1328              1080
# walkwithindia                       38                750               750
# walkwithindia                       96                750               750
# walkwithindia                       22               1296              1080
# walkwithindia                        5                750               750
# walkwithindia                       10               1349              1080
# walkwithindia                       18                750               750
# walkwithindia                       34               1325              1080
# walkwithindia                        7               1331              1080
# walkwithindia                        6               1295              1080
# walkwithindia                        6               1290              1080
# walkwithindia                       28               1321              1080
# walkwithindia                       10               1284              1080
# walkwithindia                       33               1350              1080
# walkwithindia                        4               1189              1080
# walkwithindia                       11               1323              1080
# walkwithindia                       10               1316              1080
# walkwithindia                       23               1322              1080
# walkwithindia                       11               1335              1080
# walkwithindia                        4               1334              1080
# walkwithindia                       20               1207              1080
# yourfoodlab                          8               1350              1080
#
#                                              edge_media_to_caption  \
# username
# adventurouskate  ??THE HILLS ARE ALIIIIIIIVE ?? Can you believe...
# adventurouskate  I am home, home, home. ?? Three weeks in #Ital...
# adventurouskate  Say hey to your gargoyle for me. ?? The first ...
# adventurouskate  Is it true that #Milan is a fashionable town? ...
# adventurouskate  Train life. ?? Trains are my favorite way to t...
# adventurouskate  This is the best chocolatey beverage you�ve ne...
# adventurouskate  Everything on Instagram is insanely posed, but...
# adventurouskate  #ThisIs34. ?? I�m in the closing months of bei...
# adventurouskate  Everyone is familiar with Lake Como, but there...
# adventurouskate  Confession time � ever used #Tinder on your tr...
# adventurouskate  The #Dolomites really do deliver. ? For my fin...
# adventurouskate  The #Dolomites are MAGICAL. ? Today I went on ...
# adventurouskate  Hello #Dolomites! ?? After the insanity of #Tr...
# adventurouskate  What are your feelings on...gelato? ?? When I ...
# adventurouskate  Romance on #LakeGarda. ?? My little excursion ...
# adventurouskate  #Trentino, you are SO pretty � even when you m...
# adventurouskate  Greetings from #Trentino, #Italy! How gorgeous...
# adventurouskate  Every time I go to #Italy, without failure, I ...
# adventurouskate  Greetings from #Florence, #Italy! ?? What a tr...
# adventurouskate  Did you know that #Bologna is the best food ci...
# adventurouskate  What happens when a city you love � BOLOGNA, I...
# adventurouskate  Have you ever been to the #Highline before? Th...
# adventurouskate  FASHION. ?????? I loved this @dereklam dress s...
# adventurouskate  I used to think I was a beach person. Nope. I�...
# adventurouskate  Kicking off summer in #Bushwick. ?? I have two...
# adventurouskate  I am in hardcore ITALY planning mode! ???? A w...
# adventurouskate  Sometimes a sunset can be a REALLY pink sunset...
# adventurouskate  Weird question � do you guys remember �Sharon,...
# adventurouskate  I should totally try to sell this pineapple pi...
# adventurouskate  Champagne, plunge pool, sittin� in a birdcage....
# ...                                                            ...
# walkwithindia    Peacock on lovely morning drive\r\r\n @harsha_...
# walkwithindia    Mini Tiffin 😋 perfect breakfast ? \r\r\n@thamb...
# walkwithindia    Lassi 😍❤️ summer essentials 😋\r\r\n@petukkolka...
# walkwithindia    TAG A DOSA LOVER ❤️\r\r\n@thetravellingbeee \r...
# walkwithindia    Located amidst imposing mountains in Karnataka...
# walkwithindia    Boston cream pie - 2 layers of soft vanilla ca...
# walkwithindia    “READ THE CAPTION“ do you agree on this ? 💁‍♂️...
# walkwithindia    Tag a friend ❤️ who else is craving for someth...
# walkwithindia    Tag your SQUAD! 👬👫\r\r\nVisapur Fort (also cal...
# walkwithindia    Such a mouth watering pic of jamun! 😋 tag some...
# walkwithindia    Tag a rose milk lover! 🙋🏼‍♂️ @foodtalk_chennai...
# walkwithindia    Border of Goa & Karnataka, India\r\r\nCredits ...
# walkwithindia    Mango Lassi❣️😋\r\r\n@streets_to_savories \r\r\...
# walkwithindia    If you truly love nature, you will find beauty...
# walkwithindia    Tag a Friend ❤️ tell us what’s your favourite ...
# walkwithindia    The statue of Unity!! tag a friend. \r\r\n#wal...
# walkwithindia    Chilli cheese maggi from @cafe_central_tnagar ...
# walkwithindia    It's that time of year again where we welcome ...
# walkwithindia    Wayanad, the green paradise is nestled among t...
# walkwithindia    Tag a friend and make them crave for this heal...
# walkwithindia    Beat the heat\r\r\nCredits @myvellore\r\r\n.\r...
# walkwithindia    Info park kochi\r\r\nCredits @jerin.sebastian ...
# walkwithindia    People say EAT TO LIVE\r\r\nWe say LIVE TO EAT...
# walkwithindia    SUMMER VIBES 😬 \r\r\n@jaipur_holic .\r\r\n.\r\...
# walkwithindia    Inner Peace! ( lord shiva) on the banks in Gan...
# walkwithindia    Summers are here😓 What's your pick? Left or Ri...
# walkwithindia    curly.tales\r\r\nUnicorns are real!\r\r\nThis ...
# walkwithindia    Did you know that India's tallest building is ...
# walkwithindia    Tag a friend ❤️ Caramel Brownie 🙌🏻\r\r\n@succu...
# yourfoodlab      Mutton Kheema Ghotala\r\r\n\r\r\nHave you guys...
#
#                                                               tags  \
# username
# adventurouskate    'Italy', 'southtyrol', 'dolomites', 'AltoAdige'
# adventurouskate                                'Italy', 'Florence'
# adventurouskate                                            'Milan'
# adventurouskate                                   'Italy', 'Milan'
# adventurouskate                            'Frecciarossa', 'Italy'
# adventurouskate                       'bicerin', 'Torino', 'italy'
# adventurouskate  'piemonte', 'italia', 'photographerlife', 'Mot...
# adventurouskate                                         'ThisIs34'
# adventurouskate  'Italy', 'piemonte', 'LakeMaggiore', 'lagodima...
# adventurouskate                                           'Tinder'
# adventurouskate  'italia', 'SouthTyrol', 'altoadige', 'Dolomite...
# adventurouskate                                        'Dolomites'
# adventurouskate  'Italy', 'SouthTyrol', 'Dolomites', 'Traverse1...
# adventurouskate   'Trento', 'visittrentino', 'Italy', 'Traverse19'
# adventurouskate  'Trentino', 'Italy', 'LakeGarda', 'RivaDelGard...
# adventurouskate  'Trentino', 'LakeGarda', 'visittrentino', 'Riv...
# adventurouskate  'Trentino', 'Italy', 'visittrentino', 'Trento'...
# adventurouskate                       'Vespa', 'Italy', 'Florence'
# adventurouskate                                'Italy', 'Florence'
# adventurouskate  'Bologna', 'Italy', 'Blogville', 'EmiliaRomagn...
# adventurouskate                       'Bologna', 'inEmiliaRomagna'
# adventurouskate                         'Highline', 'HighlineSpur'
# adventurouskate        'NYC', 'newyorklife', 'yellowdress', 'Soho'
# adventurouskate                                 'Vail', 'Colorado'
# adventurouskate                                         'Bushwick'
# adventurouskate                                            'Italy'
# adventurouskate  'loveantiguabarbuda', 'whatcoollookslike', 'An...
# adventurouskate  'LoveAntiguaBarbuda', 'whatcoollookslike', 'An...
# adventurouskate  'loveantiguabarbuda', 'whatcoollookslike', 'An...
# adventurouskate  'loveantiguabarbuda', 'whatcoollookslike', 'An...
# ...                                                            ...
# walkwithindia    'sunray', 'sunrays', 'earthcapture', 'bbcwildl...
# walkwithindia                           'walkwithindia', 'chennai'
# walkwithindia                                      'walkwithindia'
# walkwithindia    'southindianfood', 'chennaifoodie', 'chennai',...
# walkwithindia    'nammakarnatakaphotographers', 'karnatakafocus...
# walkwithindia                                      'walkwithindia'
# walkwithindia    'rajasthan', 'indiapictures', 'shiva', 'harhar...
# walkwithindia    'indianbreakfast', 'indianrecipes', 'indianfoo...
# walkwithindia    'mumbai', 'india_ig', 'travelgram', 'instagood...
# walkwithindia                                      'walkwithindia'
# walkwithindia                                      'walkwithindia'
# walkwithindia    'fromwhereidrone', 'goa', 'watchthisinstagood'...
# walkwithindia               'lassi', 'indianfood', 'Walkwithindia'
# walkwithindia                                      'walkwithindia'
# walkwithindia                  'india', 'walkwithindia', 'chennai'
# walkwithindia                                      'walkwithindia'
# walkwithindia                                      'walkwithindia'
# walkwithindia    'punefoodblogger', 'mango', 'livetoeat', 'food...
# walkwithindia    'keralam', 'wayanad', 'mypixeldiary', 'indianp...
# walkwithindia    'Chennaites', 'ChennaiSummer', 'FreshJuice', '...
# walkwithindia    'cmcvellore', 'myvellore', 'tender', 'vellore'...
# walkwithindia    'skypixel', 'travelgram', 'bobbyjoshi', 'drone...
# walkwithindia                                      'walkwithindia'
# walkwithindia    'mumbaiblogger', 'foodblogger', 'pastalove', '...
# walkwithindia    'lordshiva', 'walkwithindia', 'incredibleindia...
# walkwithindia    'delhistreetfood', 'foodblogger', 'illgrammer'...
# walkwithindia    'foodgoals', 'foodblogger', 'igfood', 'yummy',...
# walkwithindia    'Kolkatagram', 'kolkatadiaries', 'Calcutta', '...
# walkwithindia                    'foodietribe', 'eastcoastfoodies'
# yourfoodlab      'foodporn', 'foodislife', 'foodie', 'indiancui...
#
#                  taken_at_timestamp  shareable  popular_hashtags
# username
# adventurouskate          1561395835          1                 0
# adventurouskate          1561314723          1                 0
# adventurouskate          1561135735          1                 0
# adventurouskate          1561048759          1                 0
# adventurouskate          1560962730          1                 0
# adventurouskate          1560872721          1                 0
# adventurouskate          1560791517          1                 0
# adventurouskate          1560710313          1                 0
# adventurouskate          1560614255          1                 0
# adventurouskate          1560521258          1                 0
# adventurouskate          1560440046          1                 0
# adventurouskate          1560266601          1                 0
# adventurouskate          1560183112          1                 0
# adventurouskate          1560094851          1                 0
# adventurouskate          1560009903          1                 0
# adventurouskate          1559924932          1                 0
# adventurouskate          1559837668          1                 0
# adventurouskate          1559748612          1                 0
# adventurouskate          1559661618          1                 0
# adventurouskate          1559577978          1                 0
# adventurouskate          1559489527          1                 0
# adventurouskate          1559232624          1                 0
# adventurouskate          1559145994          1                 0
# adventurouskate          1559067134          1                 0
# adventurouskate          1558904588          1                 0
# adventurouskate          1558725403          1                 0
# adventurouskate          1558541124          1                 0
# adventurouskate          1558364758          1                 0
# adventurouskate          1558122911          1                 0
# adventurouskate          1558028731          1                 0
# ...                             ...        ...               ...
# walkwithindia            1557459946          1                 0
# walkwithindia            1557459425          1                 0
# walkwithindia            1557384532          1                 0
# walkwithindia            1557371146          1                 0
# walkwithindia            1557369596          1                 0
# walkwithindia            1557296328          1                 0
# walkwithindia            1557202829          1                 0
# walkwithindia            1557076182          1                 0
# walkwithindia            1557040113          1                 3
# walkwithindia            1557039818          1                 0
# walkwithindia            1557036470          1                 0
# walkwithindia            1556955707          1                 0
# walkwithindia            1556955147          1                 0
# walkwithindia            1556938946          1                 0
# walkwithindia            1556938259          1                 0
# walkwithindia            1556885984          1                 0
# walkwithindia            1556885836          1                 0
# walkwithindia            1556866912          1                 2
# walkwithindia            1556866120          1                 0
# walkwithindia            1556865866          1                 0
# walkwithindia            1556781308          1                 5
# walkwithindia            1556778814          1                 4
# walkwithindia            1556777820          1                 0
# walkwithindia            1556776201          1                 0
# walkwithindia            1556692248          1                 0
# walkwithindia            1556605220          1                 1
# walkwithindia            1556460346          1                 7
# walkwithindia            1556459262          1                 0
# walkwithindia            1556454706          1                 0
# yourfoodlab              1552475111          1                 5
#
# [3137 rows x 13 columns]

# %%
df=pd.read_csv('shareables.csv',encoding='utf8')
datum = df.groupby(['username']).mean()
datum=datum.rename(index=str, columns={"edge_media_preview_like": "mean_no_of_likes", "edge_media_to_comment": "mean_no_of_comments"})
datum=datum[['mean_no_of_likes','mean_no_of_comments']]
datum.to_csv(r'mean_data.csv')

# %%
df=pd.read_csv('shareables.csv',encoding='utf8')
df.index
# Out:
# RangeIndex(start=0, stop=3137, step=1)

# %%
#pd.concat([df, datum], axis=1)
datum = pd.DataFrame({"datum": ['mean_no_of_likes','mean_no_of_comments']})
#result = pd.merge(df, datum, on='username')
#result
#dat1.join(dat2)
datum
# Out:
#                  datum
# 0     mean_no_of_likes
# 1  mean_no_of_comments

# %%
datum.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df_new = pd.read_csv("new_combined_csv.csv")
df_new
# Out:
#       Unnamed: 0    shortcode          username  \
# 0              0  BziIkeqpwVe  bigboytoyz_india
# 1              1  BzaQLj_pVFP  bigboytoyz_india
# 2              2  BzPzIqTJfFQ  bigboytoyz_india
# 3              3  BzMzZrPpYC2  bigboytoyz_india
# 4              4  BzIDDGFJQg3  bigboytoyz_india
# 5              5  BzFdNK7pY0F  bigboytoyz_india
# 6              6  By8CXfahY9a  bigboytoyz_india
# 7              7  By1ylFJJ9Oi  bigboytoyz_india
# 8              8  Byw4fJ-pBAq  bigboytoyz_india
# 9              9  Bym15GQpyje  bigboytoyz_india
# 10            10  ByhUhNXp8OA  bigboytoyz_india
# 11            11  ByfKzPLJ7Np  bigboytoyz_india
# 12            12  Bycttn8J4E6  bigboytoyz_india
# 13            13  ByS7T2Ip1Km  bigboytoyz_india
# 14            14  ByNC-4dJhVG  bigboytoyz_india
# 15            15  ByKaNeWJbqp  bigboytoyz_india
# 16            16  ByC47JTJzdS  bigboytoyz_india
# 17            17  Bx_5x8Ppzwk  bigboytoyz_india
# 18            18  Bx9bmQkpclK  bigboytoyz_india
# 19            19  Bx4moK_pS66  bigboytoyz_india
# 20            20  Bx1mLwpJOjx  bigboytoyz_india
# 21            21  BxuW4YeAL1a  bigboytoyz_india
# 22            22  Bxjbz-NgfAP  bigboytoyz_india
# 23            23  BxiBDttgcuw  bigboytoyz_india
# 24            24  BxbxBp1gvpx  bigboytoyz_india
# 25            25  BxZBsu6gR8E  bigboytoyz_india
# 26            26  BxWeTNbg1TV  bigboytoyz_india
# 27            27  BxTuVxjA2vZ  bigboytoyz_india
# 28            28  BxRieUwAuAM  bigboytoyz_india
# 29            29  BxKL9sqgfuY  bigboytoyz_india
# ...          ...          ...               ...
# 2506         104  BxObAk6gNPi     walkwithindia
# 2507         105  BxMPQx2AF78     walkwithindia
# 2508         106  BxJc7PaAKJ5     walkwithindia
# 2509         107  BxFrXdSgz1G     walkwithindia
# 2510         108  BxEmkdGgneQ     walkwithindia
# 2511         109  BxEmAbSA22D     walkwithindia
# 2512         110  BxEfnvHA5p-     walkwithindia
# 2513         111  BxCFk_0AZdb     walkwithindia
# 2514         112  BxCEgqegMu8     walkwithindia
# 2515         113  BxCCPePAfy5     walkwithindia
# 2516         114  BxBlm9JgDNM     walkwithindia
# 2517         115  BxBkTGfgIwl     walkwithindia
# 2518         116  BxABqcDASxR     walkwithindia
# 2519         117  BxAAl7KAj2F     walkwithindia
# 2520         118  BxAATytgQ_9     walkwithindia
# 2521         119  Bw_cNzRA_E2     walkwithindia
# 2522         120  Bw_atJQAEdN     walkwithindia
# 2523         121  Bw_aOG2A1_F     walkwithindia
# 2524         122  Bw848EEgz7i     walkwithindia
# 2525         123  Bw80LlYg_qB     walkwithindia
# 2526         124  Bw8ySWFgFI5     walkwithindia
# 2527         125  Bw8vMrQAfqT     walkwithindia
# 2528         126  Bw6PEdhgyhp     walkwithindia
# 2529         127  Bw3pE_8A7XL     walkwithindia
# 2530         128  BwzUwJDAcIn     walkwithindia
# 2531         129  BwzSrynAPpd     walkwithindia
# 2532         130  BwzJ_rtgktD     walkwithindia
# 2533           0  BySk8YGhTFp       yourfoodlab
# 2534           1  Bw1RwoNBbGX       yourfoodlab
# 2535           2  Bu8jhPDBq9b       yourfoodlab
#
#                                             display_url  \
# 0     https://scontent-bom1-2.cdninstagram.com/vp/b7...
# 1     https://scontent-bom1-2.cdninstagram.com/vp/1f...
# 2     https://scontent-bom1-2.cdninstagram.com/vp/56...
# 3     https://scontent-bom1-2.cdninstagram.com/vp/67...
# 4     https://scontent-bom1-2.cdninstagram.com/vp/bc...
# 5     https://scontent-bom1-2.cdninstagram.com/vp/1a...
# 6     https://scontent-bom1-2.cdninstagram.com/vp/f1...
# 7     https://scontent-bom1-2.cdninstagram.com/vp/83...
# 8     https://scontent-bom1-2.cdninstagram.com/vp/c8...
# 9     https://scontent-bom1-2.cdninstagram.com/vp/ff...
# 10    https://scontent-bom1-2.cdninstagram.com/vp/8a...
# 11    https://scontent-bom1-2.cdninstagram.com/vp/ee...
# 12    https://scontent-bom1-2.cdninstagram.com/vp/0d...
# 13    https://scontent-bom1-2.cdninstagram.com/vp/0e...
# 14    https://scontent-bom1-2.cdninstagram.com/vp/24...
# 15    https://scontent-bom1-2.cdninstagram.com/vp/bb...
# 16    https://scontent-bom1-2.cdninstagram.com/vp/76...
# 17    https://scontent-bom1-2.cdninstagram.com/vp/fb...
# 18    https://scontent-bom1-2.cdninstagram.com/vp/10...
# 19    https://scontent-bom1-2.cdninstagram.com/vp/91...
# 20    https://scontent-bom1-2.cdninstagram.com/vp/cf...
# 21    https://scontent-bom1-2.cdninstagram.com/vp/8b...
# 22    https://scontent-bom1-2.cdninstagram.com/vp/9b...
# 23    https://scontent-bom1-2.cdninstagram.com/vp/94...
# 24    https://scontent-bom1-2.cdninstagram.com/vp/b4...
# 25    https://scontent-bom1-2.cdninstagram.com/vp/b2...
# 26    https://scontent-bom1-2.cdninstagram.com/vp/c6...
# 27    https://scontent-bom1-2.cdninstagram.com/vp/1f...
# 28    https://scontent-bom1-2.cdninstagram.com/vp/d8...
# 29    https://scontent-bom1-2.cdninstagram.com/vp/02...
# ...                                                 ...
# 2506  https://scontent-bom1-2.cdninstagram.com/vp/22...
# 2507  https://scontent-bom1-2.cdninstagram.com/vp/97...
# 2508  https://scontent-bom1-2.cdninstagram.com/vp/ce...
# 2509  https://scontent-bom1-2.cdninstagram.com/vp/60...
# 2510  https://scontent-bom1-2.cdninstagram.com/vp/29...
# 2511  https://scontent-bom1-2.cdninstagram.com/vp/de...
# 2512  https://scontent-bom1-2.cdninstagram.com/vp/37...
# 2513  https://scontent-bom1-2.cdninstagram.com/vp/f1...
# 2514  https://scontent-bom1-2.cdninstagram.com/vp/6e...
# 2515  https://scontent-bom1-2.cdninstagram.com/vp/bc...
# 2516  https://scontent-bom1-2.cdninstagram.com/vp/2a...
# 2517  https://scontent-bom1-2.cdninstagram.com/vp/ac...
# 2518  https://scontent-bom1-2.cdninstagram.com/vp/a5...
# 2519  https://scontent-bom1-2.cdninstagram.com/vp/fb...
# 2520  https://scontent-bom1-2.cdninstagram.com/vp/ff...
# 2521  https://scontent-bom1-2.cdninstagram.com/vp/a3...
# 2522  https://scontent-bom1-2.cdninstagram.com/vp/c5...
# 2523  https://scontent-bom1-2.cdninstagram.com/vp/0d...
# 2524  https://scontent-bom1-2.cdninstagram.com/vp/be...
# 2525  https://scontent-bom1-2.cdninstagram.com/vp/d0...
# 2526  https://scontent-bom1-2.cdninstagram.com/vp/76...
# 2527  https://scontent-bom1-2.cdninstagram.com/vp/e8...
# 2528  https://scontent-bom1-2.cdninstagram.com/vp/6a...
# 2529  https://scontent-bom1-2.cdninstagram.com/vp/de...
# 2530  https://scontent-bom1-2.cdninstagram.com/vp/3c...
# 2531  https://scontent-bom1-2.cdninstagram.com/vp/91...
# 2532  https://scontent-bom1-2.cdninstagram.com/vp/7e...
# 2533  https://scontent-bom1-2.cdninstagram.com/vp/cd...
# 2534  https://scontent-bom1-2.cdninstagram.com/vp/6a...
# 2535  https://scontent-bom1-2.cdninstagram.com/vp/96...
#
#       edge_media_preview_like  comments_disabled  edge_media_to_comment  \
# 0                       25889              False                    243
# 1                       38319              False                    214
# 2                       10152              False                     20
# 3                       36685              False                    138
# 4                       12763              False                     18
# 5                       31340              False                   1572
# 6                       51562              False                    198
# 7                       17730              False                     57
# 8                       29568              False                    382
# 9                       45224              False                   1099
# 10                      69957              False                   4166
# 11                      24051              False                     36
# 12                      39457              False                     42
# 13                      22510              False                     54
# 14                      58417              False                   1597
# 15                      28631              False                    375
# 16                      24417              False                    508
# 17                      32468              False                    462
# 18                      41866              False                    493
# 19                      21956              False                     24
# 20                      25506              False                     45
# 21                      29886              False                    264
# 22                     102904              False                   3492
# 23                      21251              False                     59
# 24                      19362              False                     15
# 25                      33257              False                    111
# 26                      29680              False                    950
# 27                      35026              False                    512
# 28                      55409              False                   1450
# 29                      46190              False                   5108
# ...                       ...                ...                    ...
# 2506                    10458              False                     31
# 2507                     4108              False                      3
# 2508                    12260              False                     77
# 2509                     5976              False                     43
# 2510                    21933              False                    331
# 2511                    10744              False                     38
# 2512                     8714              False                     96
# 2513                    10199              False                     22
# 2514                     4697              False                      5
# 2515                    11797              False                     42
# 2516                     5813              False                     10
# 2517                     5305              False                     18
# 2518                     4369              False                      3
# 2519                     5836              False                     34
# 2520                     4172              False                      7
# 2521                     4710              False                      6
# 2522                     4669              False                      6
# 2523                     7531              False                     28
# 2524                     6442              False                     10
# 2525                     9105              False                     33
# 2526                     6047              False                      4
# 2527                     3629              False                     11
# 2528                     8170              False                     10
# 2529                     6467              False                     23
# 2530                     4081              False                     11
# 2531                     3512              False                      4
# 2532                     4657              False                     20
# 2533                     7434              False                     86
# 2534                    17176              False                     44
# 2535                     4278              False                      8
#
#       dimensions_height  dimensions_width  \
# 0                   810              1080
# 1                   719              1080
# 2                  1080              1080
# 3                  1080              1080
# 4                  1080              1080
# 5                  1080              1080
# 6                  1080              1080
# 7                   607              1080
# 8                   720              1080
# 9                   809              1080
# 10                 1080              1080
# 11                  719              1080
# 12                  633              1080
# 13                 1080              1080
# 14                 1350              1080
# 15                  606              1080
# 16                 1079              1080
# 17                  720              1080
# 18                 1350              1080
# 19                 1080              1080
# 20                  720              1080
# 21                  720              1080
# 22                 1080              1080
# 23                  870               750
# 24                  608              1080
# 25                  833              1080
# 26                  914              1080
# 27                 1080              1080
# 28                 1350              1080
# 29                 1080              1080
# ...                 ...               ...
# 2506               1278              1080
# 2507                737               750
# 2508               1304              1080
# 2509               1298              1080
# 2510               1328              1080
# 2511                750               750
# 2512                750               750
# 2513               1296              1080
# 2514                750               750
# 2515               1333              1080
# 2516               1349              1080
# 2517                750               750
# 2518               1304              1080
# 2519               1325              1080
# 2520               1331              1080
# 2521               1295              1080
# 2522               1290              1080
# 2523               1321              1080
# 2524               1284              1080
# 2525               1350              1080
# 2526               1189              1080
# 2527               1323              1080
# 2528               1316              1080
# 2529               1322              1080
# 2530               1335              1080
# 2531               1334              1080
# 2532               1207              1080
# 2533               1350              1080
# 2534               1350              1080
# 2535               1350              1080
#
#                                   edge_media_to_caption  \
# 0     Giveaway Alert⚠\r\r\nWin this Lamborghini Gold...
# 1     Any Guess what we are doing next? ..\r\r\n..\r...
# 2                                     #BusinessStandard
# 3                            Call us now - 9999 9999 83
# 4     Mission and Vision @jatinahuja_official #BIGBO...
# 5                                  What would you pick?
# 6             Choose your set of Wheels at Big Boy Toyz
# 7     Caption this! \r\r\nDownload this amazing wall...
# 8            Blue or Green which side are you today at?
# 9                                     Guess this BEAST!
# 10    Giveaway Alert⚠\r\r\nWin this Maserati bag wor...
# 11    Sincere thanks from all of us!!!\r\r\n9,00,000...
# 12    Happy Birthday to the beautiful Shilpa Shetty ...
# 13    Eïd MUBARAK to everyone.\r\r\n\r\r\nWishing yo...
# 14    Guess which car Sold on this Credit Card Swipe...
# 15                 Red or Blue? \r\r\nWhat's your pick?
# 16    Giveaway ⚠️\r\r\n1) Tag 3 friends in the comme...
# 17                              Any guess what is this?
# 18    Yellow, Blue or White? \r\r\nWhat's your pick?...
# 19    Download BBT Wallpapers now!\r\r\nFollow the l...
# 20                                  Ready to transform!
# 21                                    Beauty or Beast ?
# 22    Giveaway ⚠️\r\r\n1) Tag 3 friends in the comme...
# 23                                              NEUTRAL
# 24    Download the BBT Wallpapers now!\r\r\nLink in ...
# 25    Boxes of happiness just arrived! \r\r\nStay tu...
# 26                                    Guess this beast!
# 27    Guess who is arriving at BBT ! ..\r\r\n..\r\r\...
# 28      Do u think we should Venture into Superbikes ??
# 29    Giveaway ⚠️\r\r\nSimply tag 3 friends and get ...
# ...                                                 ...
# 2506  Located amidst imposing mountains in Karnataka...
# 2507  Boston cream pie - 2 layers of soft vanilla ca...
# 2508  “READ THE CAPTION“ do you agree on this ? 💁‍♂️...
# 2509  Tag a friend ❤️ who else is craving for someth...
# 2510  Tag your SQUAD! 👬👫\r\r\nVisapur Fort (also cal...
# 2511  Such a mouth watering pic of jamun! 😋 tag some...
# 2512  Tag a rose milk lover! 🙋🏼‍♂️ @foodtalk_chennai...
# 2513  Border of Goa & Karnataka, India\r\r\nCredits ...
# 2514  Mango Lassi❣️😋\r\r\n@streets_to_savories \r\r\...
# 2515  Gundappa Donne Biryani. \r\r\nThis comes as a ...
# 2516  If you truly love nature, you will find beauty...
# 2517  Tag a Friend ❤️ tell us what’s your favourite ...
# 2518  Hunger ka instant solution 😋 @chatpati_shikha ...
# 2519  The statue of Unity!! tag a friend. \r\r\n#wal...
# 2520  Chilli cheese maggi from @cafe_central_tnagar ...
# 2521  It's that time of year again where we welcome ...
# 2522  Wayanad, the green paradise is nestled among t...
# 2523  Tag a friend and make them crave for this heal...
# 2524  Beat the heat\r\r\nCredits @myvellore\r\r\n.\r...
# 2525  Info park kochi\r\r\nCredits @jerin.sebastian ...
# 2526  People say EAT TO LIVE\r\r\nWe say LIVE TO EAT...
# 2527  SUMMER VIBES 😬 \r\r\n@jaipur_holic .\r\r\n.\r\...
# 2528  Inner Peace! ( lord shiva) on the banks in Gan...
# 2529  Summers are here😓 What's your pick? Left or Ri...
# 2530  curly.tales\r\r\nUnicorns are real!\r\r\nThis ...
# 2531  Did you know that India's tallest building is ...
# 2532  Tag a friend ❤️ Caramel Brownie 🙌🏻\r\r\n@succu...
# 2533  As a creator I have always looked up to @nasda...
# 2534  Let your voice be heard!\r\r\nGo Vote 👆🏻\r\r\n...
# 2535  Mutton Kheema Ghotala\r\r\n\r\r\nHave you guys...
#
#                                                    tags  taken_at_timestamp
# 0     ['carsofinstagram', 'Blue', 'millionairelifest...          1562325985
# 1     ['carsofinstagram', 'motoGrapher', 'supercars'...          1562061539
# 2                                  ['BusinessStandard']          1561710767
# 3                                                    []          1561610243
# 4                                        ['BIGBOYTOYZ']          1561450674
# 5                                                    []          1561363725
# 6                                                    []          1561047664
# 7                                                    []          1560838060
# 8                                                    []          1560673385
# 9                                                    []          1560336481
# 10    ['carsofinstagram', 'Blue', 'millionairelifest...          1560151211
# 11                                                   []          1560079007
# 12                           ['SuperCarsForSuperStars']          1559996648
# 13    ['2019', 'trending', 'mubarak', 'eid', 'eidmub...          1559668232
# 14                                                   []          1559470928
# 15                                                   []          1559382443
# 16    ['Strongest', 'collect', 'India', 'Supercars',...          1559130111
# 17                                                   []          1559029896
# 18    ['supercars', 'huracan', 'gallardo', 'mondaymo...          1558946963
# 19    ['Blue', 'SuperCarsforSuperStars', 'India', 'C...          1558784974
# 20                                                   []          1558684078
# 21                                                   []          1558441174
# 22    ['Gear', 'Giveaway', 'orignal', 'India', 'Gift...          1558074660
# 23                                                  NaN          1558027079
# 24    ['supercars', '488', 'Black', 'CarsOfInstagram...          1557817347
# 25                                                   []          1557725425
# 26                                                   []          1557639757
# 27    ['mumbai', 'sportsbike', 'bikeofinstagram', 'I...          1557547503
# 28                                                   []          1557474173
# 29    ['India', 'Supercars', 'Giveaway', 'Questionof...          1557227490
# ...                                                 ...                 ...
# 2506  ['nammakarnatakaphotographers', 'karnatakafocu...          1557369596
# 2507                                  ['walkwithindia']          1557296328
# 2508  ['rajasthan', 'indiapictures', 'shiva', 'harha...          1557202829
# 2509  ['indianbreakfast', 'indianrecipes', 'indianfo...          1557076182
# 2510  ['mumbai', 'india_ig', 'travelgram', 'instagoo...          1557040113
# 2511                                  ['walkwithindia']          1557039818
# 2512                                  ['walkwithindia']          1557036470
# 2513  ['fromwhereidrone', 'goa', 'watchthisinstagood...          1556955707
# 2514           ['lassi', 'indianfood', 'Walkwithindia']          1556955147
# 2515                                                 []          1556953958
# 2516                                  ['walkwithindia']          1556938946
# 2517              ['india', 'walkwithindia', 'chennai']          1556938259
# 2518                                                 []          1556886545
# 2519                                  ['walkwithindia']          1556885984
# 2520                                  ['walkwithindia']          1556885836
# 2521  ['punefoodblogger', 'mango', 'livetoeat', 'foo...          1556866912
# 2522  ['keralam', 'wayanad', 'mypixeldiary', 'indian...          1556866120
# 2523  ['Chennaites', 'ChennaiSummer', 'FreshJuice', ...          1556865866
# 2524  ['cmcvellore', 'myvellore', 'tender', 'vellore...          1556781308
# 2525  ['skypixel', 'travelgram', 'bobbyjoshi', 'dron...          1556778814
# 2526                                  ['walkwithindia']          1556777820
# 2527  ['mumbaiblogger', 'foodblogger', 'pastalove', ...          1556776201
# 2528  ['lordshiva', 'walkwithindia', 'incredibleindi...          1556692248
# 2529  ['delhistreetfood', 'foodblogger', 'illgrammer...          1556605220
# 2530  ['foodgoals', 'foodblogger', 'igfood', 'yummy'...          1556460346
# 2531  ['Kolkatagram', 'kolkatadiaries', 'Calcutta', ...          1556459262
# 2532                ['foodietribe', 'eastcoastfoodies']          1556454706
# 2533                                                 []          1559656506
# 2534                                                 []          1556525886
# 2535  ['foodporn', 'foodislife', 'foodie', 'indiancu...          1552475111
#
# [2536 rows x 12 columns]
